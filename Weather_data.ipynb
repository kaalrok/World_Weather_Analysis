# %%
# Create and Clone a git repository
# Overview of the project
# Review the Geographic Coordinate System

# %%
# Insure your API keys remain secure by adding config.py to the gitignore file in your repository

# %%
# Import dependencies
import pandas as pd
import numpy as np
import random
import timeit
import matplotlib.pyplot as plt

# add citipy library
from citipy import citipy

# add requests module
import requests

# Import the API key from config.py file
from config import weather_api_key

# import datetime to recast api date a datetime format
import time
from datetime import datetime

# %%
# Generate Random Latitude and Longitude
# Create a set of lat and long combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# the zip method combines the lats and lngs inot a list of pairs
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use citipy to determine our lat and lngs

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)

# cities
# Out:
# 764

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# print(url)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # check to see if the requests.get worked
#     print(requests.get(city_url).json())

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        current_description = city_weather["weather"][0]["description"]
#         # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Percent Humidity": city_humidity,
                          "Percent Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": current_description,
                          "Date": city_date,})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tottori
# Processing Record 2 of Set 1 | kushiro
# Processing Record 3 of Set 1 | bathsheba
# Processing Record 4 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 1 | ipora
# Processing Record 6 of Set 1 | ust-tsilma
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | faanui
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | brae
# Processing Record 11 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 1 | ribeira grande
# Processing Record 13 of Set 1 | putina
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 1 | mathbaria
# Processing Record 17 of Set 1 | russell
# Processing Record 18 of Set 1 | tauranga
# Processing Record 19 of Set 1 | gigmoto
# Processing Record 20 of Set 1 | dikson
# Processing Record 21 of Set 1 | rovaniemi
# Processing Record 22 of Set 1 | atuona
# Processing Record 23 of Set 1 | labelle
# Processing Record 24 of Set 1 | bethel
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | port elizabeth
# Processing Record 27 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 1 | nemuro
# Processing Record 29 of Set 1 | butaritari
# Processing Record 30 of Set 1 | celestun
# Processing Record 31 of Set 1 | saint-philippe
# Processing Record 32 of Set 1 | salamiyah
# Processing Record 33 of Set 1 | klyuchi
# Processing Record 34 of Set 1 | lusambo
# Processing Record 35 of Set 1 | yellowknife
# Processing Record 36 of Set 1 | aktau
# Processing Record 37 of Set 1 | asfi
# Processing Record 38 of Set 1 | ahipara
# Processing Record 39 of Set 1 | bredasdorp
# Processing Record 40 of Set 1 | coquimbo
# Processing Record 41 of Set 1 | culebra
# Processing Record 42 of Set 1 | tasiilaq
# Processing Record 43 of Set 1 | constitucion
# Processing Record 44 of Set 1 | vardo
# Processing Record 45 of Set 1 | siavonga
# Processing Record 46 of Set 1 | tiksi
# Processing Record 47 of Set 1 | puerto padre
# Processing Record 48 of Set 1 | san patricio
# Processing Record 49 of Set 1 | mataura
# Processing Record 50 of Set 1 | tuktoyaktuk
# Processing Record 1 of Set 2 | pedernales
# Processing Record 2 of Set 2 | saldanha
# Processing Record 3 of Set 2 | honolulu
# Processing Record 4 of Set 2 | jamestown
# Processing Record 5 of Set 2 | cape town
# Processing Record 6 of Set 2 | kapaa
# Processing Record 7 of Set 2 | touros
# Processing Record 8 of Set 2 | henties bay
# Processing Record 9 of Set 2 | bengkulu
# Processing Record 10 of Set 2 | daru
# Processing Record 11 of Set 2 | qaanaaq
# Processing Record 12 of Set 2 | sorland
# Processing Record 13 of Set 2 | san andres
# Processing Record 14 of Set 2 | mukhen
# Processing Record 15 of Set 2 | puerto madero
# Processing Record 16 of Set 2 | saskylakh
# Processing Record 17 of Set 2 | kamenka
# Processing Record 18 of Set 2 | puerto ayora
# Processing Record 19 of Set 2 | port hardy
# Processing Record 20 of Set 2 | tuatapere
# Processing Record 21 of Set 2 | new norfolk
# Processing Record 22 of Set 2 | chuy
# Processing Record 23 of Set 2 | sao jose da coroa grande
# Processing Record 24 of Set 2 | berdigestyakh
# Processing Record 25 of Set 2 | kavieng
# Processing Record 26 of Set 2 | clyde river
# Processing Record 27 of Set 2 | mount isa
# Processing Record 28 of Set 2 | mehamn
# Processing Record 29 of Set 2 | georgetown
# Processing Record 30 of Set 2 | kaitangata
# Processing Record 31 of Set 2 | ayorou
# Processing Record 32 of Set 2 | mar del plata
# Processing Record 33 of Set 2 | busselton
# Processing Record 34 of Set 2 | longyearbyen
# Processing Record 35 of Set 2 | tonj
# Processing Record 36 of Set 2 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 37 of Set 2 | hobart
# Processing Record 38 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 2 | kampot
# Processing Record 40 of Set 2 | nantucket
# Processing Record 41 of Set 2 | alice springs
# Processing Record 42 of Set 2 | upernavik
# Processing Record 43 of Set 2 | paragominas
# Processing Record 44 of Set 2 | bluff
# Processing Record 45 of Set 2 | castro
# Processing Record 46 of Set 2 | vila
# Processing Record 47 of Set 2 | vestmannaeyjar
# Processing Record 48 of Set 2 | mahebourg
# Processing Record 49 of Set 2 | fortuna
# Processing Record 50 of Set 2 | cabo san lucas
# Processing Record 1 of Set 3 | zyryanka
# Processing Record 2 of Set 3 | new haven
# Processing Record 3 of Set 3 | scarborough
# Processing Record 4 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 5 of Set 3 | aketi
# Processing Record 6 of Set 3 | hithadhoo
# Processing Record 7 of Set 3 | guasdualito
# Processing Record 8 of Set 3 | watertown
# Processing Record 9 of Set 3 | zhangjiakou
# Processing Record 10 of Set 3 | sherpur
# Processing Record 11 of Set 3 | korla
# Processing Record 12 of Set 3 | batagay-alyta
# Processing Record 13 of Set 3 | anadyr
# Processing Record 14 of Set 3 | hay river
# Processing Record 15 of Set 3 | lewistown
# Processing Record 16 of Set 3 | matagami
# Processing Record 17 of Set 3 | kuybysheve
# Processing Record 18 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 19 of Set 3 | hilo
# Processing Record 20 of Set 3 | camaqua
# Processing Record 21 of Set 3 | champerico
# Processing Record 22 of Set 3 | flinders
# Processing Record 23 of Set 3 | thompson
# Processing Record 24 of Set 3 | sinnamary
# Processing Record 25 of Set 3 | ternate
# Processing Record 26 of Set 3 | vaini
# Processing Record 27 of Set 3 | hermanus
# Processing Record 28 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 3 | cap malheureux
# Processing Record 32 of Set 3 | iqaluit
# Processing Record 33 of Set 3 | northfield
# Processing Record 34 of Set 3 | fare
# Processing Record 35 of Set 3 | shimoda
# Processing Record 36 of Set 3 | avarua
# Processing Record 37 of Set 3 | ustyuzhna
# Processing Record 38 of Set 3 | valparaiso
# Processing Record 39 of Set 3 | kegayli
# City not found. Skipping...
# Processing Record 40 of Set 3 | shelburne
# Processing Record 41 of Set 3 | iracoubo
# Processing Record 42 of Set 3 | grand gaube
# Processing Record 43 of Set 3 | arraial do cabo
# Processing Record 44 of Set 3 | poland
# Processing Record 45 of Set 3 | tiruvottiyur
# City not found. Skipping...
# Processing Record 46 of Set 3 | clermont
# Processing Record 47 of Set 3 | severo-kurilsk
# Processing Record 48 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 3 | truth or consequences
# Processing Record 1 of Set 4 | coahuayana
# Processing Record 2 of Set 4 | mahon
# Processing Record 3 of Set 4 | talnakh
# Processing Record 4 of Set 4 | barrow
# Processing Record 5 of Set 4 | tocopilla
# Processing Record 6 of Set 4 | oistins
# Processing Record 7 of Set 4 | hunza
# City not found. Skipping...
# Processing Record 8 of Set 4 | jujuy
# City not found. Skipping...
# Processing Record 9 of Set 4 | chartres
# Processing Record 10 of Set 4 | mitsamiouli
# Processing Record 11 of Set 4 | moerai
# Processing Record 12 of Set 4 | mangrol
# Processing Record 13 of Set 4 | mersing
# Processing Record 14 of Set 4 | waipawa
# Processing Record 15 of Set 4 | srivardhan
# Processing Record 16 of Set 4 | yamada
# Processing Record 17 of Set 4 | itarema
# Processing Record 18 of Set 4 | tautira
# Processing Record 19 of Set 4 | sri aman
# Processing Record 20 of Set 4 | bandundu
# Processing Record 21 of Set 4 | atambua
# Processing Record 22 of Set 4 | tabuk
# Processing Record 23 of Set 4 | impfondo
# Processing Record 24 of Set 4 | kyzyl-suu
# Processing Record 25 of Set 4 | husavik
# Processing Record 26 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 4 | tabory
# Processing Record 28 of Set 4 | port alfred
# Processing Record 29 of Set 4 | broken hill
# Processing Record 30 of Set 4 | palana
# Processing Record 31 of Set 4 | bella union
# Processing Record 32 of Set 4 | piacabucu
# Processing Record 33 of Set 4 | akyab
# Processing Record 34 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 4 | vanimo
# Processing Record 36 of Set 4 | lebu
# Processing Record 37 of Set 4 | skalistyy
# City not found. Skipping...
# Processing Record 38 of Set 4 | puerto quijarro
# Processing Record 39 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 4 | pangoa
# Processing Record 41 of Set 4 | khatanga
# Processing Record 42 of Set 4 | namibe
# Processing Record 43 of Set 4 | souillac
# Processing Record 44 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 4 | sitka
# Processing Record 47 of Set 4 | east london
# Processing Record 48 of Set 4 | parva
# Processing Record 49 of Set 4 | ilhabela
# Processing Record 50 of Set 4 | san andres sajcabaja
# Processing Record 1 of Set 5 | nchelenge
# Processing Record 2 of Set 5 | pevek
# Processing Record 3 of Set 5 | makat
# Processing Record 4 of Set 5 | sampit
# Processing Record 5 of Set 5 | guerrero negro
# Processing Record 6 of Set 5 | asahikawa
# Processing Record 7 of Set 5 | carnarvon
# Processing Record 8 of Set 5 | yulara
# Processing Record 9 of Set 5 | vila do maio
# Processing Record 10 of Set 5 | majene
# Processing Record 11 of Set 5 | cidreira
# Processing Record 12 of Set 5 | lodwar
# Processing Record 13 of Set 5 | ilulissat
# Processing Record 14 of Set 5 | lanycsok
# Processing Record 15 of Set 5 | seddon
# Processing Record 16 of Set 5 | yazd
# Processing Record 17 of Set 5 | kodiak
# Processing Record 18 of Set 5 | chapais
# Processing Record 19 of Set 5 | iskateley
# Processing Record 20 of Set 5 | luis gil perez
# Processing Record 21 of Set 5 | sorong
# Processing Record 22 of Set 5 | camana
# Processing Record 23 of Set 5 | maturin
# Processing Record 24 of Set 5 | san pedro
# Processing Record 25 of Set 5 | winchester
# Processing Record 26 of Set 5 | agdas
# Processing Record 27 of Set 5 | los llanos de aridane
# Processing Record 28 of Set 5 | aklavik
# Processing Record 29 of Set 5 | cherskiy
# Processing Record 30 of Set 5 | poum
# Processing Record 31 of Set 5 | ornskoldsvik
# Processing Record 32 of Set 5 | arcata
# Processing Record 33 of Set 5 | merauke
# Processing Record 34 of Set 5 | bandarbeyla
# Processing Record 35 of Set 5 | mabay
# Processing Record 36 of Set 5 | lorengau
# Processing Record 37 of Set 5 | felidhoo
# City not found. Skipping...
# Processing Record 38 of Set 5 | matara
# Processing Record 39 of Set 5 | sao joao da barra
# Processing Record 40 of Set 5 | lagoa
# Processing Record 41 of Set 5 | kang
# Processing Record 42 of Set 5 | inhambane
# Processing Record 43 of Set 5 | saint john
# Processing Record 44 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 45 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 5 | high level
# Processing Record 47 of Set 5 | nioro
# Processing Record 48 of Set 5 | fairbanks
# Processing Record 49 of Set 5 | ayagoz
# Processing Record 50 of Set 5 | kulhudhuffushi
# Processing Record 1 of Set 6 | pisco
# Processing Record 2 of Set 6 | prescott
# Processing Record 3 of Set 6 | nikolskoye
# Processing Record 4 of Set 6 | kuandian
# Processing Record 5 of Set 6 | chokurdakh
# Processing Record 6 of Set 6 | blagoveshchenka
# Processing Record 7 of Set 6 | camacha
# Processing Record 8 of Set 6 | saint-pierre
# Processing Record 9 of Set 6 | seydisehir
# Processing Record 10 of Set 6 | linxia
# Processing Record 11 of Set 6 | troitsko-pechorsk
# Processing Record 12 of Set 6 | broome
# Processing Record 13 of Set 6 | jiblah
# Processing Record 14 of Set 6 | camopi
# Processing Record 15 of Set 6 | kupang
# Processing Record 16 of Set 6 | scottsbluff
# Processing Record 17 of Set 6 | sunamganj
# City not found. Skipping...
# Processing Record 18 of Set 6 | cururupu
# Processing Record 19 of Set 6 | tazovskiy
# Processing Record 20 of Set 6 | esperance
# Processing Record 21 of Set 6 | paita
# Processing Record 22 of Set 6 | ararat
# Processing Record 23 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 6 | bharatpur
# Processing Record 25 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 6 | bemban
# Processing Record 27 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 28 of Set 6 | dmanisi
# Processing Record 29 of Set 6 | gueugnon
# Processing Record 30 of Set 6 | belaya gora
# Processing Record 31 of Set 6 | solnechnyy
# Processing Record 32 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 6 | houma
# Processing Record 34 of Set 6 | araouane
# Processing Record 35 of Set 6 | begunitsy
# Processing Record 36 of Set 6 | beckley
# Processing Record 37 of Set 6 | arroio grande
# Processing Record 38 of Set 6 | kitgum
# Processing Record 39 of Set 6 | najran
# Processing Record 40 of Set 6 | geraldton
# Processing Record 41 of Set 6 | hovd
# Processing Record 42 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 43 of Set 6 | ancud
# Processing Record 44 of Set 6 | nuuk
# Processing Record 45 of Set 6 | laibin
# Processing Record 46 of Set 6 | maceio
# Processing Record 47 of Set 6 | bambous virieux
# Processing Record 48 of Set 6 | bauchi
# Processing Record 49 of Set 6 | provideniya
# Processing Record 50 of Set 6 | tezu
# Processing Record 1 of Set 7 | warrington
# Processing Record 2 of Set 7 | zapolyarnyy
# Processing Record 3 of Set 7 | sal rei
# Processing Record 4 of Set 7 | de-kastri
# Processing Record 5 of Set 7 | burgeo
# Processing Record 6 of Set 7 | aksu
# Processing Record 7 of Set 7 | atbasar
# Processing Record 8 of Set 7 | morro bay
# Processing Record 9 of Set 7 | moose factory
# Processing Record 10 of Set 7 | baker city
# Processing Record 11 of Set 7 | lata
# Processing Record 12 of Set 7 | le port
# Processing Record 13 of Set 7 | vigrestad
# Processing Record 14 of Set 7 | kristiansund
# Processing Record 15 of Set 7 | vostok
# Processing Record 16 of Set 7 | maine-soroa
# Processing Record 17 of Set 7 | hasaki
# Processing Record 18 of Set 7 | lesosibirsk
# Processing Record 19 of Set 7 | ripoll
# Processing Record 20 of Set 7 | ponta do sol
# Processing Record 21 of Set 7 | price
# Processing Record 22 of Set 7 | shanghai
# Processing Record 23 of Set 7 | nhulunbuy
# Processing Record 24 of Set 7 | kahului
# Processing Record 25 of Set 7 | saint-augustin
# Processing Record 26 of Set 7 | vila franca do campo
# Processing Record 27 of Set 7 | petauke
# Processing Record 28 of Set 7 | chengzihe
# Processing Record 29 of Set 7 | srednekolymsk
# Processing Record 30 of Set 7 | pochutla
# Processing Record 31 of Set 7 | dhidhdhoo
# Processing Record 32 of Set 7 | eyl
# Processing Record 33 of Set 7 | durban
# Processing Record 34 of Set 7 | santo domingo
# Processing Record 35 of Set 7 | kapuskasing
# Processing Record 36 of Set 7 | waddan
# Processing Record 37 of Set 7 | tiznit
# Processing Record 38 of Set 7 | padang
# Processing Record 39 of Set 7 | dalby
# Processing Record 40 of Set 7 | port lincoln
# Processing Record 41 of Set 7 | severodvinsk
# Processing Record 42 of Set 7 | leningradskiy
# Processing Record 43 of Set 7 | gloucester
# Processing Record 44 of Set 7 | kruisfontein
# Processing Record 45 of Set 7 | saint-francois
# Processing Record 46 of Set 7 | nome
# Processing Record 47 of Set 7 | kotelnikovo
# Processing Record 48 of Set 7 | lagoa formosa
# Processing Record 49 of Set 7 | zaysan
# Processing Record 50 of Set 7 | furano
# Processing Record 1 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 3 of Set 8 | siderno
# Processing Record 4 of Set 8 | walvis bay
# Processing Record 5 of Set 8 | pangkalanbuun
# Processing Record 6 of Set 8 | klaksvik
# Processing Record 7 of Set 8 | la paz
# Processing Record 8 of Set 8 | rio gallegos
# Processing Record 9 of Set 8 | batemans bay
# Processing Record 10 of Set 8 | chkalovskoye
# Processing Record 11 of Set 8 | kadaya
# Processing Record 12 of Set 8 | mahajanga
# Processing Record 13 of Set 8 | goundi
# Processing Record 14 of Set 8 | tahta
# Processing Record 15 of Set 8 | buri
# Processing Record 16 of Set 8 | talawdi
# City not found. Skipping...
# Processing Record 17 of Set 8 | rolim de moura
# City not found. Skipping...
# Processing Record 18 of Set 8 | bantry
# Processing Record 19 of Set 8 | nein
# Processing Record 20 of Set 8 | kihei
# Processing Record 21 of Set 8 | victoria
# Processing Record 22 of Set 8 | batote
# Processing Record 23 of Set 8 | karratha
# Processing Record 24 of Set 8 | arlit
# Processing Record 25 of Set 8 | embonas
# Processing Record 26 of Set 8 | nadym
# Processing Record 27 of Set 8 | florianopolis
# Processing Record 28 of Set 8 | kamina
# Processing Record 29 of Set 8 | jijiga
# Processing Record 30 of Set 8 | leshukonskoye
# Processing Record 31 of Set 8 | vallenar
# Processing Record 32 of Set 8 | asau
# Processing Record 33 of Set 8 | canto do buriti
# Processing Record 34 of Set 8 | nkowakowa
# Processing Record 35 of Set 8 | luderitz
# Processing Record 36 of Set 8 | katsuura
# Processing Record 37 of Set 8 | sehithwa
# Processing Record 38 of Set 8 | xuddur
# Processing Record 39 of Set 8 | salalah
# Processing Record 40 of Set 8 | riverton
# Processing Record 41 of Set 8 | cascais
# Processing Record 42 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 43 of Set 8 | hutchinson
# Processing Record 44 of Set 8 | aswan
# Processing Record 45 of Set 8 | necochea
# Processing Record 46 of Set 8 | sambava
# Processing Record 47 of Set 8 | cap-aux-meules
# Processing Record 48 of Set 8 | almaznyy
# Processing Record 49 of Set 8 | komsomolskiy
# Processing Record 50 of Set 8 | mattru
# Processing Record 1 of Set 9 | tommot
# Processing Record 2 of Set 9 | mezen
# Processing Record 3 of Set 9 | abohar
# Processing Record 4 of Set 9 | veracruz
# Processing Record 5 of Set 9 | maues
# Processing Record 6 of Set 9 | jerecuaro
# Processing Record 7 of Set 9 | zhangye
# Processing Record 8 of Set 9 | luanda
# Processing Record 9 of Set 9 | dergachi
# Processing Record 10 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 11 of Set 9 | tadine
# Processing Record 12 of Set 9 | kochubey
# Processing Record 13 of Set 9 | talas
# Processing Record 14 of Set 9 | ignacio zaragoza
# Processing Record 15 of Set 9 | paamiut
# Processing Record 16 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 17 of Set 9 | antalaha
# Processing Record 18 of Set 9 | aljezur
# Processing Record 19 of Set 9 | portland
# Processing Record 20 of Set 9 | avola
# Processing Record 21 of Set 9 | kirakira
# Processing Record 22 of Set 9 | nizwa
# Processing Record 23 of Set 9 | dunedin
# Processing Record 24 of Set 9 | otjiwarongo
# Processing Record 25 of Set 9 | yakymivka
# Processing Record 26 of Set 9 | san juan
# Processing Record 27 of Set 9 | padilla
# Processing Record 28 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 29 of Set 9 | arroyo
# Processing Record 30 of Set 9 | buchanan
# Processing Record 31 of Set 9 | monte alegre de minas
# Processing Record 32 of Set 9 | jolalpan
# Processing Record 33 of Set 9 | byron bay
# Processing Record 34 of Set 9 | nabire
# Processing Record 35 of Set 9 | montalban
# Processing Record 36 of Set 9 | sindor
# Processing Record 37 of Set 9 | adrar
# Processing Record 38 of Set 9 | marsh harbour
# Processing Record 39 of Set 9 | alofi
# Processing Record 40 of Set 9 | kupino
# Processing Record 41 of Set 9 | kenora
# Processing Record 42 of Set 9 | kieta
# Processing Record 43 of Set 9 | codrington
# Processing Record 44 of Set 9 | gazli
# Processing Record 45 of Set 9 | guadalupe y calvo
# Processing Record 46 of Set 9 | san cristobal
# Processing Record 47 of Set 9 | sabirabad
# Processing Record 48 of Set 9 | kondopoga
# Processing Record 49 of Set 9 | sao filipe
# Processing Record 50 of Set 9 | uyovu
# Processing Record 1 of Set 10 | saint-denis
# Processing Record 2 of Set 10 | consett
# Processing Record 3 of Set 10 | krasnousolskiy
# City not found. Skipping...
# Processing Record 4 of Set 10 | port-gentil
# Processing Record 5 of Set 10 | rudnyy
# Processing Record 6 of Set 10 | sangar
# Processing Record 7 of Set 10 | uyuni
# Processing Record 8 of Set 10 | luziania
# Processing Record 9 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 10 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 11 of Set 10 | mount gambier
# Processing Record 12 of Set 10 | yidu
# Processing Record 13 of Set 10 | hambantota
# Processing Record 14 of Set 10 | kutum
# Processing Record 15 of Set 10 | owo
# Processing Record 16 of Set 10 | constantine
# Processing Record 17 of Set 10 | lenger
# Processing Record 18 of Set 10 | ampanihy
# Processing Record 19 of Set 10 | vestavia hills
# Processing Record 20 of Set 10 | nsanje
# Processing Record 21 of Set 10 | nanortalik
# Processing Record 22 of Set 10 | torbay
# Processing Record 23 of Set 10 | hobyo
# Processing Record 24 of Set 10 | elk grove
# Processing Record 25 of Set 10 | pohrebyshche
# Processing Record 26 of Set 10 | balikpapan
# Processing Record 27 of Set 10 | kuito
# Processing Record 28 of Set 10 | tucupita
# Processing Record 29 of Set 10 | udachnyy
# Processing Record 30 of Set 10 | magnolia
# Processing Record 31 of Set 10 | sao desiderio
# Processing Record 32 of Set 10 | port hawkesbury
# Processing Record 33 of Set 10 | cayenne
# Processing Record 34 of Set 10 | segovia
# Processing Record 35 of Set 10 | kelvington
# Processing Record 36 of Set 10 | olafsvik
# Processing Record 37 of Set 10 | laguna
# Processing Record 38 of Set 10 | komsomolets
# Processing Record 39 of Set 10 | havoysund
# Processing Record 40 of Set 10 | brownwood
# Processing Record 41 of Set 10 | larsnes
# Processing Record 42 of Set 10 | hacari
# Processing Record 43 of Set 10 | ambilobe
# Processing Record 44 of Set 10 | sungaipenuh
# Processing Record 45 of Set 10 | lopsmarka
# Processing Record 46 of Set 10 | pimentel
# Processing Record 47 of Set 10 | yining
# Processing Record 48 of Set 10 | okaihau
# Processing Record 49 of Set 10 | los andes
# Processing Record 50 of Set 10 | duzce
# Processing Record 1 of Set 11 | faya
# Processing Record 2 of Set 11 | kaitong
# Processing Record 3 of Set 11 | maroantsetra
# Processing Record 4 of Set 11 | potiskum
# Processing Record 5 of Set 11 | waingapu
# Processing Record 6 of Set 11 | teya
# Processing Record 7 of Set 11 | imeni poliny osipenko
# Processing Record 8 of Set 11 | kohima
# Processing Record 9 of Set 11 | jambi
# Processing Record 10 of Set 11 | rapid valley
# Processing Record 11 of Set 11 | ngaoundere
# Processing Record 12 of Set 11 | sabla
# Processing Record 13 of Set 11 | evans
# Processing Record 14 of Set 11 | puri
# Processing Record 15 of Set 11 | vestmanna
# Processing Record 16 of Set 11 | polovinnoye
# Processing Record 17 of Set 11 | kuanshan
# City not found. Skipping...
# Processing Record 18 of Set 11 | japura
# Processing Record 19 of Set 11 | port hedland
# Processing Record 20 of Set 11 | shimanovsk
# Processing Record 21 of Set 11 | barranca
# Processing Record 22 of Set 11 | canmore
# Processing Record 23 of Set 11 | tessalit
# Processing Record 24 of Set 11 | gizo
# Processing Record 25 of Set 11 | lipany
# Processing Record 26 of Set 11 | ellisras
# Processing Record 27 of Set 11 | chongwe
# Processing Record 28 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 29 of Set 11 | ishigaki
# Processing Record 30 of Set 11 | las vegas
# Processing Record 31 of Set 11 | banff
# Processing Record 32 of Set 11 | hamilton
# Processing Record 33 of Set 11 | chingola
# Processing Record 34 of Set 11 | jalu
# Processing Record 35 of Set 11 | potosi
# Processing Record 36 of Set 11 | honiara
# Processing Record 37 of Set 11 | port blair
# Processing Record 38 of Set 11 | lavrentiya
# Processing Record 39 of Set 11 | baykit
# Processing Record 40 of Set 11 | hailar
# Processing Record 41 of Set 11 | zhigansk
# Processing Record 42 of Set 11 | slyudyanka
# Processing Record 43 of Set 11 | yar-sale
# Processing Record 44 of Set 11 | cuddapah
# Processing Record 45 of Set 11 | babanusah
# City not found. Skipping...
# Processing Record 46 of Set 11 | pouembout
# Processing Record 47 of Set 11 | neringa
# Processing Record 48 of Set 11 | sola
# Processing Record 49 of Set 11 | khani
# Processing Record 50 of Set 11 | junction city
# Processing Record 1 of Set 12 | tilichiki
# Processing Record 2 of Set 12 | ritchie
# Processing Record 3 of Set 12 | omutinskoye
# City not found. Skipping...
# Processing Record 4 of Set 12 | strezhevoy
# Processing Record 5 of Set 12 | xiashi
# Processing Record 6 of Set 12 | harper
# Processing Record 7 of Set 12 | eydhafushi
# Processing Record 8 of Set 12 | oranjemund
# Processing Record 9 of Set 12 | avera
# Processing Record 10 of Set 12 | smithers
# Processing Record 11 of Set 12 | ketchikan
# Processing Record 12 of Set 12 | mundra
# Processing Record 13 of Set 12 | chegdomyn
# Processing Record 14 of Set 12 | kibiti
# Processing Record 15 of Set 12 | bubaque
# Processing Record 16 of Set 12 | egvekinot
# Processing Record 17 of Set 12 | muisne
# Processing Record 18 of Set 12 | korfovskiy
# Processing Record 19 of Set 12 | carballo
# Processing Record 20 of Set 12 | bairiki
# Processing Record 21 of Set 12 | elat
# Processing Record 22 of Set 12 | wajir
# Processing Record 23 of Set 12 | dongning
# Processing Record 24 of Set 12 | suba
# Processing Record 25 of Set 12 | fenoarivo
# Processing Record 26 of Set 12 | aksarka
# Processing Record 27 of Set 12 | abu samrah
# Processing Record 28 of Set 12 | lakes entrance
# Processing Record 29 of Set 12 | nicoya
# Processing Record 30 of Set 12 | haines junction
# Processing Record 31 of Set 12 | ginir
# Processing Record 32 of Set 12 | tierralta
# Processing Record 33 of Set 12 | muros
# Processing Record 34 of Set 12 | ariquemes
# Processing Record 35 of Set 12 | paracuru
# Processing Record 36 of Set 12 | miamisburg
# Processing Record 37 of Set 12 | nador
# Processing Record 38 of Set 12 | itoman
# Processing Record 39 of Set 12 | samarai
# Processing Record 40 of Set 12 | bonavista
# Processing Record 41 of Set 12 | tukrah
# Processing Record 42 of Set 12 | gryazi
# Processing Record 43 of Set 12 | prieska
# Processing Record 44 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 45 of Set 12 | katherine
# Processing Record 46 of Set 12 | shenjiamen
# Processing Record 47 of Set 12 | olbia
# Processing Record 48 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 49 of Set 12 | shiraz
# Processing Record 50 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 1 of Set 13 | pulandian
# Processing Record 2 of Set 13 | adeje
# Processing Record 3 of Set 13 | atar
# Processing Record 4 of Set 13 | doume
# Processing Record 5 of Set 13 | kavaratti
# Processing Record 6 of Set 13 | plouzane
# Processing Record 7 of Set 13 | noumea
# Processing Record 8 of Set 13 | bukama
# Processing Record 9 of Set 13 | ozinki
# Processing Record 10 of Set 13 | itainopolis
# Processing Record 11 of Set 13 | marzuq
# Processing Record 12 of Set 13 | kuna
# Processing Record 13 of Set 13 | alihe
# Processing Record 14 of Set 13 | tapaua
# City not found. Skipping...
# Processing Record 15 of Set 13 | vilcun
# Processing Record 16 of Set 13 | soavinandriana
# Processing Record 17 of Set 13 | la libertad
# Processing Record 18 of Set 13 | le vauclin
# Processing Record 19 of Set 13 | svetlaya
# Processing Record 20 of Set 13 | praia
# Processing Record 21 of Set 13 | thanatpin
# Processing Record 22 of Set 13 | pampa
# Processing Record 23 of Set 13 | kasempa
# Processing Record 24 of Set 13 | vao
# Processing Record 25 of Set 13 | marsabit
# Processing Record 26 of Set 13 | independencia
# Processing Record 27 of Set 13 | norman wells
# Processing Record 28 of Set 13 | fukue
# Processing Record 29 of Set 13 | kloulklubed
# Processing Record 30 of Set 13 | skibbereen
# Processing Record 31 of Set 13 | dingle
# Processing Record 32 of Set 13 | yirol
# City not found. Skipping...
# Processing Record 33 of Set 13 | lompoc
# Processing Record 34 of Set 13 | san quintin
# Processing Record 35 of Set 13 | plattsburgh
# Processing Record 36 of Set 13 | eucaliptus
# Processing Record 37 of Set 13 | atagay
# Processing Record 38 of Set 13 | muli
# Processing Record 39 of Set 13 | airai
# Processing Record 40 of Set 13 | rio grande
# Processing Record 41 of Set 13 | chimore
# Processing Record 42 of Set 13 | semirom
# Processing Record 43 of Set 13 | shieli
# Processing Record 44 of Set 13 | guicheng
# City not found. Skipping...
# Processing Record 45 of Set 13 | kilindoni
# Processing Record 46 of Set 13 | the valley
# Processing Record 47 of Set 13 | nelson bay
# Processing Record 48 of Set 13 | mogadishu
# Processing Record 49 of Set 13 | shizukuishi
# Processing Record 50 of Set 13 | ahuimanu
# Processing Record 1 of Set 14 | dzhebariki-khaya
# Processing Record 2 of Set 14 | wajima
# Processing Record 3 of Set 14 | griffith
# Processing Record 4 of Set 14 | denpasar
# Processing Record 5 of Set 14 | tonota
# Processing Record 6 of Set 14 | duz
# City not found. Skipping...
# Processing Record 7 of Set 14 | bilibino
# Processing Record 8 of Set 14 | mlawa
# Processing Record 9 of Set 14 | oga
# Processing Record 10 of Set 14 | quatre cocos
# Processing Record 11 of Set 14 | zemio
# Processing Record 12 of Set 14 | yurimaguas
# Processing Record 13 of Set 14 | eskil
# Processing Record 14 of Set 14 | virginia beach
# Processing Record 15 of Set 14 | zachagansk
# City not found. Skipping...
# Processing Record 16 of Set 14 | coihaique
# Processing Record 17 of Set 14 | linhares
# Processing Record 18 of Set 14 | gjusvik
# City not found. Skipping...
# Processing Record 19 of Set 14 | amahai
# Processing Record 20 of Set 14 | dubai
# Processing Record 21 of Set 14 | wewak
# Processing Record 22 of Set 14 | pierre
# Processing Record 23 of Set 14 | mergui
# City not found. Skipping...
# Processing Record 24 of Set 14 | mitu
# Processing Record 25 of Set 14 | erzin
# Processing Record 26 of Set 14 | prado
# Processing Record 27 of Set 14 | belmonte
# Processing Record 28 of Set 14 | port dover
# Processing Record 29 of Set 14 | bogovina
# Processing Record 30 of Set 14 | shangzhi
# Processing Record 31 of Set 14 | luancheng
# Processing Record 32 of Set 14 | puerto escondido
# Processing Record 33 of Set 14 | belyy yar
# Processing Record 34 of Set 14 | sandila
# Processing Record 35 of Set 14 | goderich
# Processing Record 36 of Set 14 | ravar
# Processing Record 37 of Set 14 | cabedelo
# Processing Record 38 of Set 14 | gravdal
# Processing Record 39 of Set 14 | grindavik
# Processing Record 40 of Set 14 | acapulco
# Processing Record 41 of Set 14 | dibaya
# City not found. Skipping...
# Processing Record 42 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 43 of Set 14 | kintampo
# Processing Record 44 of Set 14 | kirovskiy
# Processing Record 45 of Set 14 | graaff-reinet
# Processing Record 46 of Set 14 | homer
# Processing Record 47 of Set 14 | quelimane
# Processing Record 48 of Set 14 | bilma
# Processing Record 49 of Set 14 | mayo
# Processing Record 50 of Set 14 | ostrovnoy
# Processing Record 1 of Set 15 | sicuani
# Processing Record 2 of Set 15 | lephepe
# City not found. Skipping...
# Processing Record 3 of Set 15 | ust-tarka
# Processing Record 4 of Set 15 | mandalgovi
# Processing Record 5 of Set 15 | krasnoselkup
# Processing Record 6 of Set 15 | callaway
# Processing Record 7 of Set 15 | lima
# Processing Record 8 of Set 15 | rabo de peixe
# Processing Record 9 of Set 15 | salinopolis
# Processing Record 10 of Set 15 | witu
# Processing Record 11 of Set 15 | gamba
# Processing Record 12 of Set 15 | codajas
# Processing Record 13 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 14 of Set 15 | bambanglipuro
# Processing Record 15 of Set 15 | wyndham
# Processing Record 16 of Set 15 | lugo
# Processing Record 17 of Set 15 | weston
# Processing Record 18 of Set 15 | taos
# Processing Record 19 of Set 15 | kuteynykove
# Processing Record 20 of Set 15 | coolum beach
# Processing Record 21 of Set 15 | jales
# Processing Record 22 of Set 15 | turtas
# Processing Record 23 of Set 15 | mizdah
# Processing Record 24 of Set 15 | kapoeta
# Processing Record 25 of Set 15 | santo tomas
# Processing Record 26 of Set 15 | soma
# Processing Record 27 of Set 15 | yerbogachen
# Processing Record 28 of Set 15 | riyadh
# Processing Record 29 of Set 15 | kokstad
# Processing Record 30 of Set 15 | shingu
# Processing Record 31 of Set 15 | huntington
# Processing Record 32 of Set 15 | liuzhou
# Processing Record 33 of Set 15 | ust-kuyga
# Processing Record 34 of Set 15 | artyom
# Processing Record 35 of Set 15 | katobu
# Processing Record 36 of Set 15 | lohja
# Processing Record 37 of Set 15 | mochitlan
# City not found. Skipping...
# Processing Record 38 of Set 15 | karauli
# Processing Record 39 of Set 15 | luwuk
# Processing Record 40 of Set 15 | asyut
# Processing Record 41 of Set 15 | narsaq
# Processing Record 42 of Set 15 | marawi
# Processing Record 43 of Set 15 | kaduqli
# Processing Record 44 of Set 15 | berlevag
# Processing Record 45 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 46 of Set 15 | khasan
# Processing Record 47 of Set 15 | batagay
# Processing Record 48 of Set 15 | westport
# Processing Record 49 of Set 15 | maumere
# Processing Record 50 of Set 15 | ormara
# Processing Record 1 of Set 16 | leh
# Processing Record 2 of Set 16 | pindiga
# Processing Record 3 of Set 16 | buala
# Processing Record 4 of Set 16 | bereda
# Processing Record 5 of Set 16 | sur
# Processing Record 6 of Set 16 | zeerust
# Processing Record 7 of Set 16 | liverpool
# Processing Record 8 of Set 16 | espinosa
# Processing Record 9 of Set 16 | pitimbu
# Processing Record 10 of Set 16 | solsvik
# City not found. Skipping...
# Processing Record 11 of Set 16 | taman
# Processing Record 12 of Set 16 | abu dhabi
# Processing Record 13 of Set 16 | shimoni
# Processing Record 14 of Set 16 | amapa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'Tottori',
#   'Lat': 35.5,
#   'Lng': 134.2333,
#   'Max Temp': 55.47,
#   'Percent Humidity': 94,
#   'Percent Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Country': 'JP',
#   'Current Description': 'shower rain',
#   'Date': '2022-04-29 02:04:59'},
#  {'City': 'Kushiro',
#   'Lat': 42.975,
#   'Lng': 144.3747,
#   'Max Temp': 47.73,
#   'Percent Humidity': 48,
#   'Percent Cloudiness': 98,
#   'Wind Speed': 15.41,
#   'Country': 'JP',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:06:06'},
#  {'City': 'Bathsheba',
#   'Lat': 13.2167,
#   'Lng': -59.5167,
#   'Max Temp': 79.41,
#   'Percent Humidity': 89,
#   'Percent Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Country': 'BB',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:06:06'},
#  {'City': 'Ipora',
#   'Lat': -16.4419,
#   'Lng': -51.1178,
#   'Max Temp': 68.36,
#   'Percent Humidity': 59,
#   'Percent Cloudiness': 4,
#   'Wind Speed': 3.11,
#   'Country': 'BR',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:02:34'},
#  {'City': 'Ust-Tsilma',
#   'Lat': 65.441,
#   'Lng': 52.1498,
#   'Max Temp': 25.27,
#   'Percent Humidity': 82,
#   'Percent Cloudiness': 25,
#   'Wind Speed': 8.41,
#   'Country': 'RU',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:06:08'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 77.05,
#   'Percent Humidity': 69,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 18.34,
#   'Country': 'PF',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:00:40'},
#  {'City': 'Faanui',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 81.46,
#   'Percent Humidity': 72,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 21.54,
#   'Country': 'PF',
#   'Current Description': 'light rain',
#   'Date': '2022-04-29 02:06:08'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 40.66,
#   'Percent Humidity': 87,
#   'Percent Cloudiness': 40,
#   'Wind Speed': 27.63,
#   'Country': 'AR',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:06:09'},
#  {'City': 'Brae',
#   'Lat': 60.3964,
#   'Lng': -1.353,
#   'Max Temp': 44.8,
#   'Percent Humidity': 81,
#   'Percent Cloudiness': 94,
#   'Wind Speed': 5.68,
#   'Country': 'GB',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:06:09'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 63.59,
#   'Percent Humidity': 84,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 20.71,
#   'Country': 'PT',
#   'Current Description': 'light rain',
#   'Date': '2022-04-29 02:06:10'},
#  {'City': 'Putina',
#   'Lat': -15.4667,
#   'Lng': -69.4333,
#   'Max Temp': 40.78,
#   'Percent Humidity': 83,
#   'Percent Cloudiness': 12,
#   'Wind Speed': 8.39,
#   'Country': 'PE',
#   'Current Description': 'few clouds',
#   'Date': '2022-04-29 02:06:11'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 43.63,
#   'Percent Humidity': 34,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 7,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:06:11'},
#  {'City': 'Mathbaria',
#   'Lat': 22.2876,
#   'Lng': 89.9593,
#   'Max Temp': 88.48,
#   'Percent Humidity': 58,
#   'Percent Cloudiness': 44,
#   'Wind Speed': 7.49,
#   'Country': 'BD',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:06:12'},
#  {'City': 'Russell',
#   'Lat': 32.3502,
#   'Lng': -85.1999,
#   'Max Temp': 69.03,
#   'Percent Humidity': 77,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:06:13'},
#  {'City': 'Tauranga',
#   'Lat': -37.6861,
#   'Lng': 176.1667,
#   'Max Temp': 66.15,
#   'Percent Humidity': 26,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 4.9,
#   'Country': 'NZ',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:06:13'},
#  {'City': 'Gigmoto',
#   'Lat': 13.7796,
#   'Lng': 124.39,
#   'Max Temp': 84.97,
#   'Percent Humidity': 73,
#   'Percent Cloudiness': 27,
#   'Wind Speed': 10.87,
#   'Country': 'PH',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:06:14'},
#  {'City': 'Dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 9.77,
#   'Percent Humidity': 91,
#   'Percent Cloudiness': 22,
#   'Wind Speed': 20.69,
#   'Country': 'RU',
#   'Current Description': 'few clouds',
#   'Date': '2022-04-29 02:06:14'},
#  {'City': 'Rovaniemi',
#   'Lat': 66.5,
#   'Lng': 25.7167,
#   'Max Temp': 24.21,
#   'Percent Humidity': 63,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'FI',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:01:53'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 79.36,
#   'Percent Humidity': 74,
#   'Percent Cloudiness': 58,
#   'Wind Speed': 19.62,
#   'Country': 'PF',
#   'Current Description': 'broken clouds',
#   'Date': '2022-04-29 02:06:15'},
#  {'City': 'Labelle',
#   'Lat': 26.7617,
#   'Lng': -81.4384,
#   'Max Temp': 71.98,
#   'Percent Humidity': 83,
#   'Percent Cloudiness': 71,
#   'Wind Speed': 7.63,
#   'Country': 'US',
#   'Current Description': 'broken clouds',
#   'Date': '2022-04-29 02:06:16'},
#  {'City': 'Bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 47.48,
#   'Percent Humidity': 38,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:05:23'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 42.12,
#   'Percent Humidity': 75,
#   'Percent Cloudiness': 99,
#   'Wind Speed': 17.22,
#   'Country': 'CL',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:00:44'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 63.32,
#   'Percent Humidity': 66,
#   'Percent Cloudiness': 4,
#   'Wind Speed': 3,
#   'Country': 'ZA',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:06:17'},
#  {'City': 'Nemuro',
#   'Lat': 43.3236,
#   'Lng': 145.575,
#   'Max Temp': 42.15,
#   'Percent Humidity': 65,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 11.1,
#   'Country': 'JP',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:06:18'},
#  {'City': 'Butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 82.06,
#   'Percent Humidity': 77,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 15.93,
#   'Country': 'KI',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:03:02'},
#  {'City': 'Celestun',
#   'Lat': 20.8667,
#   'Lng': -90.4,
#   'Max Temp': 78.04,
#   'Percent Humidity': 71,
#   'Percent Cloudiness': 27,
#   'Wind Speed': 15.57,
#   'Country': 'MX',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:06:19'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 74.79,
#   'Percent Humidity': 79,
#   'Percent Cloudiness': 46,
#   'Wind Speed': 13.11,
#   'Country': 'RE',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:06:19'},
#  {'City': 'Salamiyah',
#   'Lat': 35.0113,
#   'Lng': 37.0532,
#   'Max Temp': 64.49,
#   'Percent Humidity': 49,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 1.68,
#   'Country': 'SY',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:06:20'},
#  {'City': 'Klyuchi',
#   'Lat': 52.2667,
#   'Lng': 79.1667,
#   'Max Temp': 61.56,
#   'Percent Humidity': 42,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 11.41,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:06:20'},
#  {'City': 'Lusambo',
#   'Lat': -4.9667,
#   'Lng': 23.45,
#   'Max Temp': 69.35,
#   'Percent Humidity': 99,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 1.16,
#   'Country': 'CD',
#   'Current Description': 'moderate rain',
#   'Date': '2022-04-29 02:06:21'},
#  {'City': 'Yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 33.57,
#   'Percent Humidity': 64,
#   'Percent Cloudiness': 25,
#   'Wind Speed': 18.99,
#   'Country': 'CA',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:02:48'},
#  {'City': 'Aktau',
#   'Lat': 43.65,
#   'Lng': 51.2,
#   'Max Temp': 61.38,
#   'Percent Humidity': 49,
#   'Percent Cloudiness': 6,
#   'Wind Speed': 10.2,
#   'Country': 'KZ',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:06:22'},
#  {'City': 'Asfi',
#   'Lat': 32.2994,
#   'Lng': -9.2372,
#   'Max Temp': 57.6,
#   'Percent Humidity': 78,
#   'Percent Cloudiness': 50,
#   'Wind Speed': 14.72,
#   'Country': 'MA',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:02:53'},
#  {'City': 'Ahipara',
#   'Lat': -35.1667,
#   'Lng': 173.1667,
#   'Max Temp': 67.01,
#   'Percent Humidity': 60,
#   'Percent Cloudiness': 39,
#   'Wind Speed': 5.86,
#   'Country': 'NZ',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:06:22'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 56.57,
#   'Percent Humidity': 95,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 6.44,
#   'Country': 'ZA',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:05:27'},
#  {'City': 'Coquimbo',
#   'Lat': -29.9533,
#   'Lng': -71.3436,
#   'Max Temp': 60.33,
#   'Percent Humidity': 76,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 4.07,
#   'Country': 'CL',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:04:14'},
#  {'City': 'Culebra',
#   'Lat': 18.303,
#   'Lng': -65.301,
#   'Max Temp': 78.84,
#   'Percent Humidity': 76,
#   'Percent Cloudiness': 22,
#   'Wind Speed': 5.99,
#   'Country': 'PR',
#   'Current Description': 'few clouds',
#   'Date': '2022-04-29 02:06:23'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 28.56,
#   'Percent Humidity': 84,
#   'Percent Cloudiness': 60,
#   'Wind Speed': 5.55,
#   'Country': 'GL',
#   'Current Description': 'broken clouds',
#   'Date': '2022-04-29 02:06:24'},
#  {'City': 'Constitucion',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 49.71,
#   'Percent Humidity': 70,
#   'Percent Cloudiness': 4,
#   'Wind Speed': 7.18,
#   'Country': 'CL',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:06:25'},
#  {'City': 'Vardo',
#   'Lat': 70.3705,
#   'Lng': 31.1107,
#   'Max Temp': 26.89,
#   'Percent Humidity': 61,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 22.7,
#   'Country': 'NO',
#   'Current Description': 'light snow',
#   'Date': '2022-04-29 02:06:25'},
#  {'City': 'Siavonga',
#   'Lat': -16.5382,
#   'Lng': 28.7088,
#   'Max Temp': 67.96,
#   'Percent Humidity': 71,
#   'Percent Cloudiness': 88,
#   'Wind Speed': 3.83,
#   'Country': 'ZM',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:06:26'},
#  {'City': 'Tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': 18.9,
#   'Percent Humidity': 81,
#   'Percent Cloudiness': 83,
#   'Wind Speed': 8.39,
#   'Country': 'RU',
#   'Current Description': 'broken clouds',
#   'Date': '2022-04-29 02:06:26'},
#  {'City': 'Puerto Padre',
#   'Lat': 21.195,
#   'Lng': -76.6028,
#   'Max Temp': 73.35,
#   'Percent Humidity': 68,
#   'Percent Cloudiness': 17,
#   'Wind Speed': 8.79,
#   'Country': 'CU',
#   'Current Description': 'few clouds',
#   'Date': '2022-04-29 02:06:27'},
#  {'City': 'San Patricio',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 77.09,
#   'Percent Humidity': 81,
#   'Percent Cloudiness': 23,
#   'Wind Speed': 13.53,
#   'Country': 'US',
#   'Current Description': 'few clouds',
#   'Date': '2022-04-29 02:06:27'},
#  {'City': 'Mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 57.47,
#   'Percent Humidity': 62,
#   'Percent Cloudiness': 8,
#   'Wind Speed': 0.92,
#   'Country': 'NZ',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:03:39'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': 15.89,
#   'Percent Humidity': 92,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 9.93,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:06:28'},
#  {'City': 'Pedernales',
#   'Lat': 18.0384,
#   'Lng': -71.744,
#   'Max Temp': 76.17,
#   'Percent Humidity': 71,
#   'Percent Cloudiness': 15,
#   'Wind Speed': 5.99,
#   'Country': 'DO',
#   'Current Description': 'few clouds',
#   'Date': '2022-04-29 02:07:29'},
#  {'City': 'Saldanha',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 60.12,
#   'Percent Humidity': 86,
#   'Percent Cloudiness': 37,
#   'Wind Speed': 9.28,
#   'Country': 'ZA',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:07:29'},
#  {'City': 'Honolulu',
#   'Lat': 21.3069,
#   'Lng': -157.8583,
#   'Max Temp': 83.44,
#   'Percent Humidity': 64,
#   'Percent Cloudiness': 40,
#   'Wind Speed': 13.8,
#   'Country': 'US',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:05:02'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 35.71,
#   'Percent Humidity': 60,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:07:30'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 60.89,
#   'Percent Humidity': 88,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'ZA',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:07:30'},
#  {'City': 'Kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 78.48,
#   'Percent Humidity': 81,
#   'Percent Cloudiness': 32,
#   'Wind Speed': 5.99,
#   'Country': 'US',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:03:40'},
#  {'City': 'Touros',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 77.14,
#   'Percent Humidity': 89,
#   'Percent Cloudiness': 91,
#   'Wind Speed': 10.18,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:04:06'},
#  {'City': 'Henties Bay',
#   'Lat': -22.116,
#   'Lng': 14.2845,
#   'Max Temp': 63.54,
#   'Percent Humidity': 69,
#   'Percent Cloudiness': 32,
#   'Wind Speed': 6.76,
#   'Country': 'NA',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:07:31'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 82.29,
#   'Percent Humidity': 72,
#   'Percent Cloudiness': 98,
#   'Wind Speed': 3.49,
#   'Country': 'ID',
#   'Current Description': 'moderate rain',
#   'Date': '2022-04-29 02:07:32'},
#  {'City': 'Daru',
#   'Lat': -9.0763,
#   'Lng': 143.2092,
#   'Max Temp': 84.56,
#   'Percent Humidity': 71,
#   'Percent Cloudiness': 98,
#   'Wind Speed': 10.6,
#   'Country': 'PG',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:07:32'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 15.31,
#   'Percent Humidity': 90,
#   'Percent Cloudiness': 77,
#   'Wind Speed': 7.65,
#   'Country': 'GL',
#   'Current Description': 'broken clouds',
#   'Date': '2022-04-29 02:07:33'},
#  {'City': 'Sorland',
#   'Lat': 67.667,
#   'Lng': 12.6934,
#   'Max Temp': 35.08,
#   'Percent Humidity': 60,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 14.23,
#   'Country': 'NO',
#   'Current Description': 'light snow',
#   'Date': '2022-04-29 02:07:33'},
#  {'City': 'San Andres',
#   'Lat': 12.5847,
#   'Lng': -81.7006,
#   'Max Temp': 80.62,
#   'Percent Humidity': 78,
#   'Percent Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'CO',
#   'Current Description': 'broken clouds',
#   'Date': '2022-04-29 02:07:34'},
#  {'City': 'Mukhen',
#   'Lat': 48.1,
#   'Lng': 136.1,
#   'Max Temp': 52.09,
#   'Percent Humidity': 32,
#   'Percent Cloudiness': 26,
#   'Wind Speed': 11.16,
#   'Country': 'RU',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:07:34'},
#  {'City': 'Puerto Madero',
#   'Lat': 14.7208,
#   'Lng': -92.4215,
#   'Max Temp': 82.6,
#   'Percent Humidity': 83,
#   'Percent Cloudiness': 40,
#   'Wind Speed': 2.3,
#   'Country': 'MX',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:07:35'},
#  {'City': 'Saskylakh',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': 21.6,
#   'Percent Humidity': 82,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 8.16,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:07:36'},
#  {'City': 'Kamenka',
#   'Lat': 51.3223,
#   'Lng': 42.7678,
#   'Max Temp': 43,
#   'Percent Humidity': 65,
#   'Percent Cloudiness': 98,
#   'Wind Speed': 7.07,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:07:36'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 71.76,
#   'Percent Humidity': 91,
#   'Percent Cloudiness': 3,
#   'Wind Speed': 6.98,
#   'Country': 'EC',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:07:37'},
#  {'City': 'Port Hardy',
#   'Lat': 50.6996,
#   'Lng': -127.4199,
#   'Max Temp': 50.18,
#   'Percent Humidity': 66,
#   'Percent Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'CA',
#   'Current Description': 'light intensity shower rain',
#   'Date': '2022-04-29 02:07:37'},
#  {'City': 'Tuatapere',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 58.05,
#   'Percent Humidity': 67,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 2.01,
#   'Country': 'NZ',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:03:39'},
#  {'City': 'New Norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 71.92,
#   'Percent Humidity': 76,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 5.01,
#   'Country': 'AU',
#   'Current Description': 'moderate rain',
#   'Date': '2022-04-29 02:07:38'},
#  {'City': 'Chuy',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 48.94,
#   'Percent Humidity': 68,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 8.77,
#   'Country': 'UY',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:07:38'},
#  {'City': 'Sao Jose Da Coroa Grande',
#   'Lat': -8.8978,
#   'Lng': -35.1478,
#   'Max Temp': 77.97,
#   'Percent Humidity': 77,
#   'Percent Cloudiness': 98,
#   'Wind Speed': 8.97,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:07:39'},
#  {'City': 'Berdigestyakh',
#   'Lat': 62.0989,
#   'Lng': 126.6992,
#   'Max Temp': 34.18,
#   'Percent Humidity': 73,
#   'Percent Cloudiness': 24,
#   'Wind Speed': 4.81,
#   'Country': 'RU',
#   'Current Description': 'few clouds',
#   'Date': '2022-04-29 02:07:39'},
#  {'City': 'Kavieng',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 86.31,
#   'Percent Humidity': 64,
#   'Percent Cloudiness': 31,
#   'Wind Speed': 6.08,
#   'Country': 'PG',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:07:40'},
#  {'City': 'Clyde River',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': 3.43,
#   'Percent Humidity': 92,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 4.61,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:07:35'},
#  {'City': 'Mount Isa',
#   'Lat': -20.7333,
#   'Lng': 139.5,
#   'Max Temp': 89.37,
#   'Percent Humidity': 45,
#   'Percent Cloudiness': 45,
#   'Wind Speed': 12.66,
#   'Country': 'AU',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:07:41'},
#  {'City': 'Mehamn',
#   'Lat': 71.0357,
#   'Lng': 27.8492,
#   'Max Temp': 25.97,
#   'Percent Humidity': 82,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 17.85,
#   'Country': 'NO',
#   'Current Description': 'light snow',
#   'Date': '2022-04-29 02:07:41'},
#  {'City': 'Georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 85.95,
#   'Percent Humidity': 79,
#   'Percent Cloudiness': 20,
#   'Wind Speed': 0,
#   'Country': 'MY',
#   'Current Description': 'few clouds',
#   'Date': '2022-04-29 02:07:32'},
#  {'City': 'Kaitangata',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 55.15,
#   'Percent Humidity': 70,
#   'Percent Cloudiness': 1,
#   'Wind Speed': 3.8,
#   'Country': 'NZ',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:07:42'},
#  {'City': 'Ayorou',
#   'Lat': 14.7308,
#   'Lng': 0.9174,
#   'Max Temp': 84.02,
#   'Percent Humidity': 16,
#   'Percent Cloudiness': 65,
#   'Wind Speed': 9.44,
#   'Country': 'NE',
#   'Current Description': 'broken clouds',
#   'Date': '2022-04-29 02:07:43'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 46.87,
#   'Percent Humidity': 83,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 14,
#   'Country': 'AR',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:07:43'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 62.6,
#   'Percent Humidity': 59,
#   'Percent Cloudiness': 3,
#   'Wind Speed': 1.48,
#   'Country': 'AU',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:00:51'},
#  {'City': 'Longyearbyen',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 6.64,
#   'Percent Humidity': 61,
#   'Percent Cloudiness': 20,
#   'Wind Speed': 14.97,
#   'Country': 'SJ',
#   'Current Description': 'few clouds',
#   'Date': '2022-04-29 02:07:44'},
#  {'City': 'Tonj',
#   'Lat': 7.2737,
#   'Lng': 28.6822,
#   'Max Temp': 76.37,
#   'Percent Humidity': 69,
#   'Percent Cloudiness': 97,
#   'Wind Speed': 5.37,
#   'Country': 'SS',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:07:44'},
#  {'City': 'Hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 72.27,
#   'Percent Humidity': 71,
#   'Percent Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'AU',
#   'Current Description': 'moderate rain',
#   'Date': '2022-04-29 02:07:45'},
#  {'City': 'Petropavlovsk-Kamchatskiy',
#   'Lat': 53.0452,
#   'Lng': 158.6483,
#   'Max Temp': 45.19,
#   'Percent Humidity': 61,
#   'Percent Cloudiness': 75,
#   'Wind Speed': 11.18,
#   'Country': 'RU',
#   'Current Description': 'broken clouds',
#   'Date': '2022-04-29 02:03:22'},
#  {'City': 'Kampot',
#   'Lat': 10.6167,
#   'Lng': 104.1833,
#   'Max Temp': 84.25,
#   'Percent Humidity': 68,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 3.06,
#   'Country': 'KH',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:07:46'},
#  {'City': 'Nantucket',
#   'Lat': 41.2835,
#   'Lng': -70.0995,
#   'Max Temp': 50.11,
#   'Percent Humidity': 48,
#   'Percent Cloudiness': 20,
#   'Wind Speed': 18.41,
#   'Country': 'US',
#   'Current Description': 'few clouds',
#   'Date': '2022-04-29 02:07:46'},
#  {'City': 'Alice Springs',
#   'Lat': -23.7,
#   'Lng': 133.8833,
#   'Max Temp': 90.95,
#   'Percent Humidity': 17,
#   'Percent Cloudiness': 1,
#   'Wind Speed': 10.36,
#   'Country': 'AU',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:07:46'},
#  {'City': 'Upernavik',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 13.82,
#   'Percent Humidity': 93,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 5.14,
#   'Country': 'GL',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:07:47'},
#  {'City': 'Paragominas',
#   'Lat': -2.9667,
#   'Lng': -47.4833,
#   'Max Temp': 72.82,
#   'Percent Humidity': 96,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 2.66,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:03:14'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 57.79,
#   'Percent Humidity': 69,
#   'Percent Cloudiness': 35,
#   'Wind Speed': 4.21,
#   'Country': 'NZ',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:07:48'},
#  {'City': 'Castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 62.24,
#   'Percent Humidity': 90,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 3.94,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:07:33'},
#  {'City': 'Vila',
#   'Lat': 42.0304,
#   'Lng': -8.1588,
#   'Max Temp': 45.48,
#   'Percent Humidity': 86,
#   'Percent Cloudiness': 52,
#   'Wind Speed': 4,
#   'Country': 'PT',
#   'Current Description': 'broken clouds',
#   'Date': '2022-04-29 02:07:49'},
#  {'City': 'Vestmannaeyjar',
#   'Lat': 63.4427,
#   'Lng': -20.2734,
#   'Max Temp': 46,
#   'Percent Humidity': 84,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 1.92,
#   'Country': 'IS',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:07:49'},
#  {'City': 'Mahebourg',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 74.25,
#   'Percent Humidity': 94,
#   'Percent Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Country': 'MU',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:07:50'},
#  {'City': 'Fortuna',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 56.93,
#   'Percent Humidity': 65,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:07:38'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 79.11,
#   'Percent Humidity': 50,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 0,
#   'Country': 'MX',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:07:51'},
#  {'City': 'Zyryanka',
#   'Lat': 65.75,
#   'Lng': 150.85,
#   'Max Temp': 22.89,
#   'Percent Humidity': 82,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 11.88,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:08:51'},
#  {'City': 'New Haven',
#   'Lat': 41.4001,
#   'Lng': -72.9329,
#   'Max Temp': 48.06,
#   'Percent Humidity': 29,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 21,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:06:52'},
#  {'City': 'Scarborough',
#   'Lat': 54.2797,
#   'Lng': -0.4044,
#   'Max Temp': 37.9,
#   'Percent Humidity': 87,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 0.6,
#   'Country': 'GB',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:08:07'},
#  {'City': 'Aketi',
#   'Lat': 2.7388,
#   'Lng': 23.7833,
#   'Max Temp': 68.7,
#   'Percent Humidity': 99,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 1.48,
#   'Country': 'CD',
#   'Current Description': 'light rain',
#   'Date': '2022-04-29 02:08:52'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 84.67,
#   'Percent Humidity': 65,
#   'Percent Cloudiness': 36,
#   'Wind Speed': 4.27,
#   'Country': 'MV',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:08:02'},
#  {'City': 'Guasdualito',
#   'Lat': 7.2424,
#   'Lng': -70.7324,
#   'Max Temp': 80.74,
#   'Percent Humidity': 67,
#   'Percent Cloudiness': 94,
#   'Wind Speed': 1.45,
#   'Country': 'VE',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:08:53'},
#  {'City': 'Watertown',
#   'Lat': 42.3709,
#   'Lng': -71.1828,
#   'Max Temp': 47.08,
#   'Percent Humidity': 33,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:07:43'},
#  {'City': 'Zhangjiakou',
#   'Lat': 40.81,
#   'Lng': 114.8794,
#   'Max Temp': 56.79,
#   'Percent Humidity': 45,
#   'Percent Cloudiness': 97,
#   'Wind Speed': 4.85,
#   'Country': 'CN',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:08:54'},
#  {'City': 'Sherpur',
#   'Lat': 25.0188,
#   'Lng': 90.0175,
#   'Max Temp': 86.67,
#   'Percent Humidity': 69,
#   'Percent Cloudiness': 2,
#   'Wind Speed': 11.86,
#   'Country': 'BD',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:08:54'},
#  {'City': 'Korla',
#   'Lat': 41.7597,
#   'Lng': 86.1469,
#   'Max Temp': 55.47,
#   'Percent Humidity': 41,
#   'Percent Cloudiness': 54,
#   'Wind Speed': 2.39,
#   'Country': 'CN',
#   'Current Description': 'broken clouds',
#   'Date': '2022-04-29 02:08:55'},
#  {'City': 'Batagay-Alyta',
#   'Lat': 67.8006,
#   'Lng': 130.4114,
#   'Max Temp': 18.64,
#   'Percent Humidity': 80,
#   'Percent Cloudiness': 15,
#   'Wind Speed': 4.63,
#   'Country': 'RU',
#   'Current Description': 'few clouds',
#   'Date': '2022-04-29 02:08:55'},
#  {'City': 'Anadyr',
#   'Lat': 64.75,
#   'Lng': 177.4833,
#   'Max Temp': 32.5,
#   'Percent Humidity': 69,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Country': 'RU',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:08:56'},
#  {'City': 'Hay River',
#   'Lat': 60.8156,
#   'Lng': -115.7999,
#   'Max Temp': 35.04,
#   'Percent Humidity': 80,
#   'Percent Cloudiness': 29,
#   'Wind Speed': 8.25,
#   'Country': 'CA',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:08:56'},
#  {'City': 'Lewistown',
#   'Lat': 40.5992,
#   'Lng': -77.5714,
#   'Max Temp': 47.61,
#   'Percent Humidity': 23,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:08:57'},
#  {'City': 'Matagami',
#   'Lat': 49.7502,
#   'Lng': -77.6328,
#   'Max Temp': 30.31,
#   'Percent Humidity': 64,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Country': 'CA',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:08:57'},
#  {'City': 'Kuybysheve',
#   'Lat': 47.358,
#   'Lng': 36.6491,
#   'Max Temp': 55.18,
#   'Percent Humidity': 63,
#   'Percent Cloudiness': 97,
#   'Wind Speed': 6.17,
#   'Country': 'UA',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:05:21'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 80.28,
#   'Percent Humidity': 77,
#   'Percent Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Country': 'US',
#   'Current Description': 'few clouds',
#   'Date': '2022-04-29 02:05:30'},
#  {'City': 'Camaqua',
#   'Lat': -30.8511,
#   'Lng': -51.8122,
#   'Max Temp': 57.92,
#   'Percent Humidity': 97,
#   'Percent Cloudiness': 32,
#   'Wind Speed': 4.29,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:08:59'},
#  {'City': 'Champerico',
#   'Lat': 14.3,
#   'Lng': -91.9167,
#   'Max Temp': 85.03,
#   'Percent Humidity': 65,
#   'Percent Cloudiness': 6,
#   'Wind Speed': 4.79,
#   'Country': 'GT',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:08:59'},
#  {'City': 'Flinders',
#   'Lat': -34.5833,
#   'Lng': 150.8552,
#   'Max Temp': 81.05,
#   'Percent Humidity': 70,
#   'Percent Cloudiness': 47,
#   'Wind Speed': 7,
#   'Country': 'AU',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:09:00'},
#  {'City': 'Thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 35.38,
#   'Percent Humidity': 90,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 6.17,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:04:43'},
#  {'City': 'Sinnamary',
#   'Lat': 5.3833,
#   'Lng': -52.95,
#   'Max Temp': 77.97,
#   'Percent Humidity': 87,
#   'Percent Cloudiness': 87,
#   'Wind Speed': 11.43,
#   'Country': 'GF',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:04:38'},
#  {'City': 'Ternate',
#   'Lat': 0.8,
#   'Lng': 127.4,
#   'Max Temp': 83.8,
#   'Percent Humidity': 71,
#   'Percent Cloudiness': 95,
#   'Wind Speed': 4.88,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:09:01'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 82.56,
#   'Percent Humidity': 65,
#   'Percent Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Country': 'TO',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:09:01'},
#  {'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 60.98,
#   'Percent Humidity': 89,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 6.64,
#   'Country': 'ZA',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:06:55'},
#  {'City': 'Cap Malheureux',
#   'Lat': -19.9842,
#   'Lng': 57.6142,
#   'Max Temp': 74.46,
#   'Percent Humidity': 78,
#   'Percent Cloudiness': 12,
#   'Wind Speed': 3,
#   'Country': 'MU',
#   'Current Description': 'few clouds',
#   'Date': '2022-04-29 02:09:03'},
#  {'City': 'Iqaluit',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': -7.56,
#   'Percent Humidity': 89,
#   'Percent Cloudiness': 98,
#   'Wind Speed': 1.54,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:09:03'},
#  {'City': 'Northfield',
#   'Lat': 44.4583,
#   'Lng': -93.1616,
#   'Max Temp': 50.72,
#   'Percent Humidity': 69,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:09:04'},
#  {'City': 'Fare',
#   'Lat': -16.7,
#   'Lng': -151.0167,
#   'Max Temp': 81.84,
#   'Percent Humidity': 70,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 22.03,
#   'Country': 'PF',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:09:04'},
#  {'City': 'Shimoda',
#   'Lat': 34.6667,
#   'Lng': 138.95,
#   'Max Temp': 59.36,
#   'Percent Humidity': 85,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 15.19,
#   'Country': 'JP',
#   'Current Description': 'moderate rain',
#   'Date': '2022-04-29 02:09:05'},
#  {'City': 'Avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 80.65,
#   'Percent Humidity': 83,
#   'Percent Cloudiness': 20,
#   'Wind Speed': 12.66,
#   'Country': 'CK',
#   'Current Description': 'few clouds',
#   'Date': '2022-04-29 02:07:45'},
#  {'City': 'Ustyuzhna',
#   'Lat': 58.8394,
#   'Lng': 36.4321,
#   'Max Temp': 27.93,
#   'Percent Humidity': 63,
#   'Percent Cloudiness': 77,
#   'Wind Speed': 5.37,
#   'Country': 'RU',
#   'Current Description': 'broken clouds',
#   'Date': '2022-04-29 02:09:06'},
#  {'City': 'Valparaiso',
#   'Lat': -33.0393,
#   'Lng': -71.6273,
#   'Max Temp': 59.47,
#   'Percent Humidity': 65,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Country': 'CL',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:05:26'},
#  {'City': 'Shelburne',
#   'Lat': 44.0787,
#   'Lng': -80.2041,
#   'Max Temp': 33.6,
#   'Percent Humidity': 53,
#   'Percent Cloudiness': 4,
#   'Wind Speed': 5.86,
#   'Country': 'CA',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:09:07'},
#  {'City': 'Iracoubo',
#   'Lat': 5.4802,
#   'Lng': -53.2011,
#   'Max Temp': 78.19,
#   'Percent Humidity': 86,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 11.88,
#   'Country': 'GF',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:09:07'},
#  {'City': 'Grand Gaube',
#   'Lat': -20.0064,
#   'Lng': 57.6608,
#   'Max Temp': 74.37,
#   'Percent Humidity': 78,
#   'Percent Cloudiness': 10,
#   'Wind Speed': 3,
#   'Country': 'MU',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:09:08'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 75.25,
#   'Percent Humidity': 88,
#   'Percent Cloudiness': 1,
#   'Wind Speed': 19.19,
#   'Country': 'BR',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:09:09'},
#  {'City': 'Poland',
#   'Lat': 44.0606,
#   'Lng': -70.3937,
#   'Max Temp': 44.92,
#   'Percent Humidity': 38,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:09:09'},
#  {'City': 'Clermont',
#   'Lat': 49.5,
#   'Lng': 2.4167,
#   'Max Temp': 47.01,
#   'Percent Humidity': 78,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 8.34,
#   'Country': 'FR',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:09:10'},
#  {'City': 'Severo-Kurilsk',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 35.33,
#   'Percent Humidity': 91,
#   'Percent Cloudiness': 89,
#   'Wind Speed': 18.03,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:09:11'},
#  {'City': 'Truth Or Consequences',
#   'Lat': 33.1284,
#   'Lng': -107.2528,
#   'Max Temp': 79.03,
#   'Percent Humidity': 7,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 14.97,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:09:12'},
#  {'City': 'Coahuayana',
#   'Lat': 18.7333,
#   'Lng': -103.6833,
#   'Max Temp': 74.41,
#   'Percent Humidity': 81,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 2.44,
#   'Country': 'MX',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:10:12'},
#  {'City': 'Mahon',
#   'Lat': 39.8885,
#   'Lng': 4.2658,
#   'Max Temp': 57.76,
#   'Percent Humidity': 94,
#   'Percent Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Country': 'ES',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:05:56'},
#  {'City': 'Talnakh',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': 15.21,
#   'Percent Humidity': 78,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 4.05,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:10:13'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': 8.62,
#   'Percent Humidity': 78,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 20.71,
#   'Country': 'US',
#   'Current Description': 'light snow',
#   'Date': '2022-04-29 02:10:13'},
#  {'City': 'Tocopilla',
#   'Lat': -22.092,
#   'Lng': -70.1979,
#   'Max Temp': 64.87,
#   'Percent Humidity': 78,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 3.69,
#   'Country': 'CL',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:10:14'},
#  {'City': 'Oistins',
#   'Lat': 13.0667,
#   'Lng': -59.5333,
#   'Max Temp': 78.89,
#   'Percent Humidity': 89,
#   'Percent Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Country': 'BB',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:09:58'},
#  {'City': 'Chartres',
#   'Lat': 48.4167,
#   'Lng': 1.5,
#   'Max Temp': 51.71,
#   'Percent Humidity': 82,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 5.01,
#   'Country': 'FR',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:10:15'},
#  {'City': 'Mitsamiouli',
#   'Lat': -11.3847,
#   'Lng': 43.2844,
#   'Max Temp': 80.8,
#   'Percent Humidity': 73,
#   'Percent Cloudiness': 70,
#   'Wind Speed': 18.45,
#   'Country': 'KM',
#   'Current Description': 'broken clouds',
#   'Date': '2022-04-29 02:10:16'},
#  {'City': 'Moerai',
#   'Lat': -22.4333,
#   'Lng': -151.3333,
#   'Max Temp': 80.08,
#   'Percent Humidity': 66,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 18.12,
#   'Country': 'PF',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:10:16'},
#  {'City': 'Mangrol',
#   'Lat': 21.1167,
#   'Lng': 70.1167,
#   'Max Temp': 83.16,
#   'Percent Humidity': 71,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 11.7,
#   'Country': 'IN',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:10:17'},
#  {'City': 'Mersing',
#   'Lat': 2.4312,
#   'Lng': 103.8405,
#   'Max Temp': 83.98,
#   'Percent Humidity': 75,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 3.89,
#   'Country': 'MY',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:10:18'},
#  {'City': 'Waipawa',
#   'Lat': -41.4122,
#   'Lng': 175.5153,
#   'Max Temp': 57.47,
#   'Percent Humidity': 58,
#   'Percent Cloudiness': 7,
#   'Wind Speed': 7.65,
#   'Country': 'NZ',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:10:18'},
#  {'City': 'Srivardhan',
#   'Lat': 18.0333,
#   'Lng': 73.0167,
#   'Max Temp': 82.29,
#   'Percent Humidity': 82,
#   'Percent Cloudiness': 6,
#   'Wind Speed': 2.86,
#   'Country': 'IN',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:10:19'},
#  {'City': 'Yamada',
#   'Lat': 39.4667,
#   'Lng': 141.95,
#   'Max Temp': 50.34,
#   'Percent Humidity': 45,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 7.74,
#   'Country': 'JP',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:10:19'},
#  {'City': 'Itarema',
#   'Lat': -2.9248,
#   'Lng': -39.9167,
#   'Max Temp': 76.39,
#   'Percent Humidity': 89,
#   'Percent Cloudiness': 21,
#   'Wind Speed': 6.67,
#   'Country': 'BR',
#   'Current Description': 'few clouds',
#   'Date': '2022-04-29 02:10:20'},
#  {'City': 'Tautira',
#   'Lat': -17.7333,
#   'Lng': -149.15,
#   'Max Temp': 80.17,
#   'Percent Humidity': 76,
#   'Percent Cloudiness': 23,
#   'Wind Speed': 21.03,
#   'Country': 'PF',
#   'Current Description': 'light rain',
#   'Date': '2022-04-29 02:10:20'},
#  {'City': 'Sri Aman',
#   'Lat': 1.2376,
#   'Lng': 111.4621,
#   'Max Temp': 84.76,
#   'Percent Humidity': 72,
#   'Percent Cloudiness': 83,
#   'Wind Speed': 3.4,
#   'Country': 'MY',
#   'Current Description': 'broken clouds',
#   'Date': '2022-04-29 02:10:21'},
#  {'City': 'Bandundu',
#   'Lat': -3.3167,
#   'Lng': 17.3667,
#   'Max Temp': 70.79,
#   'Percent Humidity': 96,
#   'Percent Cloudiness': 41,
#   'Wind Speed': 1.77,
#   'Country': 'CD',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:10:21'},
#  {'City': 'Atambua',
#   'Lat': -9.1061,
#   'Lng': 124.8925,
#   'Max Temp': 83.43,
#   'Percent Humidity': 55,
#   'Percent Cloudiness': 42,
#   'Wind Speed': 1.59,
#   'Country': 'ID',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:10:22'},
#  {'City': 'Tabuk',
#   'Lat': 17.4189,
#   'Lng': 121.4443,
#   'Max Temp': 87.3,
#   'Percent Humidity': 56,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 6.49,
#   'Country': 'PH',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:10:22'},
#  {'City': 'Impfondo',
#   'Lat': 1.6381,
#   'Lng': 18.0667,
#   'Max Temp': 72.16,
#   'Percent Humidity': 90,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 0.51,
#   'Country': 'CG',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:10:23'},
#  {'City': 'Kyzyl-Suu',
#   'Lat': 42.3414,
#   'Lng': 78.0056,
#   'Max Temp': 49.55,
#   'Percent Humidity': 31,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 1.99,
#   'Country': 'KG',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:10:23'},
#  {'City': 'Husavik',
#   'Lat': 66.0449,
#   'Lng': -17.3389,
#   'Max Temp': 42.31,
#   'Percent Humidity': 67,
#   'Percent Cloudiness': 8,
#   'Wind Speed': 5.57,
#   'Country': 'IS',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:10:24'},
#  {'City': 'Tabory',
#   'Lat': 58.5198,
#   'Lng': 64.5495,
#   'Max Temp': 38.68,
#   'Percent Humidity': 78,
#   'Percent Cloudiness': 99,
#   'Wind Speed': 9.1,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:10:25'},
#  {'City': 'Port Alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 66.97,
#   'Percent Humidity': 52,
#   'Percent Cloudiness': 10,
#   'Wind Speed': 9.69,
#   'Country': 'ZA',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:07:59'},
#  {'City': 'Broken Hill',
#   'Lat': -31.95,
#   'Lng': 141.4333,
#   'Max Temp': 76.96,
#   'Percent Humidity': 32,
#   'Percent Cloudiness': 99,
#   'Wind Speed': 13.38,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:10:26'},
#  {'City': 'Palana',
#   'Lat': 59.1167,
#   'Lng': 159.9667,
#   'Max Temp': 35.02,
#   'Percent Humidity': 69,
#   'Percent Cloudiness': 6,
#   'Wind Speed': 18.19,
#   'Country': 'RU',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:10:26'},
#  {'City': 'Bella Union',
#   'Lat': -30.2752,
#   'Lng': -57.6007,
#   'Max Temp': 53.94,
#   'Percent Humidity': 81,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 8.63,
#   'Country': 'UY',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:10:27'},
#  {'City': 'Piacabucu',
#   'Lat': -10.4056,
#   'Lng': -36.4344,
#   'Max Temp': 76.19,
#   'Percent Humidity': 83,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 6.11,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:10:27'},
#  {'City': 'Akyab',
#   'Lat': 20.15,
#   'Lng': 92.9,
#   'Max Temp': 83.88,
#   'Percent Humidity': 73,
#   'Percent Cloudiness': 4,
#   'Wind Speed': 3.4,
#   'Country': 'MM',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:10:28'},
#  {'City': 'Vanimo',
#   'Lat': -2.6741,
#   'Lng': 141.3028,
#   'Max Temp': 87.19,
#   'Percent Humidity': 62,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 4.12,
#   'Country': 'PG',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:10:29'},
#  {'City': 'Lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 48.54,
#   'Percent Humidity': 80,
#   'Percent Cloudiness': 1,
#   'Wind Speed': 16.37,
#   'Country': 'CL',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:07:59'},
#  {'City': 'Puerto Quijarro',
#   'Lat': -17.7833,
#   'Lng': -57.7667,
#   'Max Temp': 83.07,
#   'Percent Humidity': 41,
#   'Percent Cloudiness': 84,
#   'Wind Speed': 2.26,
#   'Country': 'BO',
#   'Current Description': 'broken clouds',
#   'Date': '2022-04-29 02:10:30'},
#  {'City': 'Pangoa',
#   'Lat': -12.1167,
#   'Lng': -73,
#   'Max Temp': 67.46,
#   'Percent Humidity': 99,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 2.33,
#   'Country': 'PE',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:10:31'},
#  {'City': 'Khatanga',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': 17.1,
#   'Percent Humidity': 90,
#   'Percent Cloudiness': 63,
#   'Wind Speed': 2.53,
#   'Country': 'RU',
#   'Current Description': 'broken clouds',
#   'Date': '2022-04-29 02:07:13'},
#  {'City': 'Namibe',
#   'Lat': -15.1961,
#   'Lng': 12.1522,
#   'Max Temp': 73,
#   'Percent Humidity': 70,
#   'Percent Cloudiness': 5,
#   'Wind Speed': 5.03,
#   'Country': 'AO',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:10:32'},
#  {'City': 'Souillac',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 71.98,
#   'Percent Humidity': 94,
#   'Percent Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Country': 'MU',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:01:30'},
#  {'City': 'Sitka',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 51.69,
#   'Percent Humidity': 62,
#   'Percent Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Country': 'US',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:10:33'},
#  {'City': 'East London',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 69.66,
#   'Percent Humidity': 45,
#   'Percent Cloudiness': 3,
#   'Wind Speed': 8.77,
#   'Country': 'ZA',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:10:33'},
#  {'City': 'Parva',
#   'Lat': 47.4,
#   'Lng': 24.55,
#   'Max Temp': 41.88,
#   'Percent Humidity': 94,
#   'Percent Cloudiness': 89,
#   'Wind Speed': 5.91,
#   'Country': 'RO',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:10:34'},
#  {'City': 'Ilhabela',
#   'Lat': -23.7781,
#   'Lng': -45.3581,
#   'Max Temp': 76.84,
#   'Percent Humidity': 73,
#   'Percent Cloudiness': 68,
#   'Wind Speed': 4.14,
#   'Country': 'BR',
#   'Current Description': 'broken clouds',
#   'Date': '2022-04-29 02:08:47'},
#  {'City': 'San Andres Sajcabaja',
#   'Lat': 15.2167,
#   'Lng': -90.9167,
#   'Max Temp': 65.79,
#   'Percent Humidity': 90,
#   'Percent Cloudiness': 49,
#   'Wind Speed': 3.74,
#   'Country': 'GT',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:10:35'},
#  {'City': 'Nchelenge',
#   'Lat': -9.3451,
#   'Lng': 28.734,
#   'Max Temp': 63.48,
#   'Percent Humidity': 91,
#   'Percent Cloudiness': 71,
#   'Wind Speed': 7.29,
#   'Country': 'ZM',
#   'Current Description': 'broken clouds',
#   'Date': '2022-04-29 02:11:35'},
#  {'City': 'Pevek',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': 29.03,
#   'Percent Humidity': 94,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 9.17,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:11:36'},
#  {'City': 'Makat',
#   'Lat': 47.6469,
#   'Lng': 53.3463,
#   'Max Temp': 64.72,
#   'Percent Humidity': 52,
#   'Percent Cloudiness': 10,
#   'Wind Speed': 1.66,
#   'Country': 'KZ',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:11:37'},
#  {'City': 'Sampit',
#   'Lat': -2.5333,
#   'Lng': 112.95,
#   'Max Temp': 87.49,
#   'Percent Humidity': 67,
#   'Percent Cloudiness': 39,
#   'Wind Speed': 0.69,
#   'Country': 'ID',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:11:37'},
#  {'City': 'Guerrero Negro',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 60.21,
#   'Percent Humidity': 72,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 20.67,
#   'Country': 'MX',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:08:36'},
#  {'City': 'Asahikawa',
#   'Lat': 43.7678,
#   'Lng': 142.3703,
#   'Max Temp': 51.85,
#   'Percent Humidity': 29,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 9.01,
#   'Country': 'JP',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:11:38'},
#  {'City': 'Carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 75.27,
#   'Percent Humidity': 41,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 19.57,
#   'Country': 'AU',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:07:34'},
#  {'City': 'Yulara',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 75.04,
#   'Percent Humidity': 38,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 12.66,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:09:13'},
#  {'City': 'Vila Do Maio',
#   'Lat': 15.1333,
#   'Lng': -23.2167,
#   'Max Temp': 70.66,
#   'Percent Humidity': 80,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 15.61,
#   'Country': 'CV',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:11:39'},
#  {'City': 'Majene',
#   'Lat': -3.5403,
#   'Lng': 118.9707,
#   'Max Temp': 86.18,
#   'Percent Humidity': 67,
#   'Percent Cloudiness': 55,
#   'Wind Speed': 5.99,
#   'Country': 'ID',
#   'Current Description': 'broken clouds',
#   'Date': '2022-04-29 02:07:25'},
#  {'City': 'Cidreira',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 66.27,
#   'Percent Humidity': 86,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 7.58,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:11:19'},
#  {'City': 'Lodwar',
#   'Lat': 3.1191,
#   'Lng': 35.5973,
#   'Max Temp': 76.62,
#   'Percent Humidity': 75,
#   'Percent Cloudiness': 72,
#   'Wind Speed': 2.53,
#   'Country': 'KE',
#   'Current Description': 'broken clouds',
#   'Date': '2022-04-29 02:11:40'},
#  {'City': 'Ilulissat',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 26.62,
#   'Percent Humidity': 93,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 0,
#   'Country': 'GL',
#   'Current Description': 'light snow',
#   'Date': '2022-04-29 02:11:41'},
#  {'City': 'Lanycsok',
#   'Lat': 46.0054,
#   'Lng': 18.6253,
#   'Max Temp': 49.33,
#   'Percent Humidity': 91,
#   'Percent Cloudiness': 28,
#   'Wind Speed': 6.22,
#   'Country': 'HU',
# ...
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:24:30'},
#  {'City': 'Homer',
#   'Lat': 59.6425,
#   'Lng': -151.5483,
#   'Max Temp': 48.79,
#   'Percent Humidity': 51,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 17,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:24:30'},
#  {'City': 'Quelimane',
#   'Lat': -17.8786,
#   'Lng': 36.8883,
#   'Max Temp': 69.75,
#   'Percent Humidity': 94,
#   'Percent Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Country': 'MZ',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:24:31'},
#  {'City': 'Bilma',
#   'Lat': 18.6853,
#   'Lng': 12.9164,
#   'Max Temp': 85.15,
#   'Percent Humidity': 10,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 9.26,
#   'Country': 'NE',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:24:31'},
#  {'City': 'Mayo',
#   'Lat': 38.8876,
#   'Lng': -76.5119,
#   'Max Temp': 53.55,
#   'Percent Humidity': 53,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:24:32'},
#  {'City': 'Ostrovnoy',
#   'Lat': 68.0531,
#   'Lng': 39.5131,
#   'Max Temp': 15.06,
#   'Percent Humidity': 86,
#   'Percent Cloudiness': 57,
#   'Wind Speed': 19.62,
#   'Country': 'RU',
#   'Current Description': 'broken clouds',
#   'Date': '2022-04-29 02:24:32'},
#  {'City': 'Sicuani',
#   'Lat': -14.2694,
#   'Lng': -71.2261,
#   'Max Temp': 44.55,
#   'Percent Humidity': 83,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 2.19,
#   'Country': 'PE',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:25:33'},
#  {'City': 'Ust-Tarka',
#   'Lat': 55.5672,
#   'Lng': 75.705,
#   'Max Temp': 63.5,
#   'Percent Humidity': 43,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 13.8,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:25:34'},
#  {'City': 'Mandalgovi',
#   'Lat': 45.7625,
#   'Lng': 106.2708,
#   'Max Temp': 35.73,
#   'Percent Humidity': 27,
#   'Percent Cloudiness': 3,
#   'Wind Speed': 19.15,
#   'Country': 'MN',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:25:34'},
#  {'City': 'Krasnoselkup',
#   'Lat': 65.7,
#   'Lng': 82.4667,
#   'Max Temp': 27.14,
#   'Percent Humidity': 95,
#   'Percent Cloudiness': 98,
#   'Wind Speed': 12.53,
#   'Country': 'RU',
#   'Current Description': 'light snow',
#   'Date': '2022-04-29 02:25:35'},
#  {'City': 'Callaway',
#   'Lat': 30.153,
#   'Lng': -85.5699,
#   'Max Temp': 70,
#   'Percent Humidity': 83,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:25:35'},
#  {'City': 'Lima',
#   'Lat': -12.0432,
#   'Lng': -77.0282,
#   'Max Temp': 68.9,
#   'Percent Humidity': 76,
#   'Percent Cloudiness': 20,
#   'Wind Speed': 6.91,
#   'Country': 'PE',
#   'Current Description': 'few clouds',
#   'Date': '2022-04-29 02:23:08'},
#  {'City': 'Rabo De Peixe',
#   'Lat': 37.8,
#   'Lng': -25.5833,
#   'Max Temp': 63.28,
#   'Percent Humidity': 88,
#   'Percent Cloudiness': 75,
#   'Wind Speed': 19.57,
#   'Country': 'PT',
#   'Current Description': 'light intensity drizzle rain',
#   'Date': '2022-04-29 02:25:36'},
#  {'City': 'Salinopolis',
#   'Lat': -0.6136,
#   'Lng': -47.3561,
#   'Max Temp': 77.72,
#   'Percent Humidity': 89,
#   'Percent Cloudiness': 88,
#   'Wind Speed': 9.71,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:21:30'},
#  {'City': 'Witu',
#   'Lat': -2.3889,
#   'Lng': 40.4382,
#   'Max Temp': 78.96,
#   'Percent Humidity': 91,
#   'Percent Cloudiness': 96,
#   'Wind Speed': 7.96,
#   'Country': 'KE',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:25:37'},
#  {'City': 'Gamba',
#   'Lat': -2.65,
#   'Lng': 10,
#   'Max Temp': 76.28,
#   'Percent Humidity': 90,
#   'Percent Cloudiness': 57,
#   'Wind Speed': 1.45,
#   'Country': 'GA',
#   'Current Description': 'broken clouds',
#   'Date': '2022-04-29 02:25:37'},
#  {'City': 'Codajas',
#   'Lat': -3.8367,
#   'Lng': -62.0569,
#   'Max Temp': 74.73,
#   'Percent Humidity': 98,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 2.84,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:25:38'},
#  {'City': 'Bambanglipuro',
#   'Lat': -7.95,
#   'Lng': 110.2833,
#   'Max Temp': 83.26,
#   'Percent Humidity': 76,
#   'Percent Cloudiness': 47,
#   'Wind Speed': 4.34,
#   'Country': 'ID',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:25:39'},
#  {'City': 'Wyndham',
#   'Lat': 37.6985,
#   'Lng': -77.6125,
#   'Max Temp': 48.94,
#   'Percent Humidity': 73,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:25:39'},
#  {'City': 'Lugo',
#   'Lat': 43,
#   'Lng': -7.5,
#   'Max Temp': 45.91,
#   'Percent Humidity': 100,
#   'Percent Cloudiness': 39,
#   'Wind Speed': 0.36,
#   'Country': 'ES',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:25:40'},
#  {'City': 'Weston',
#   'Lat': 26.1004,
#   'Lng': -80.3998,
#   'Max Temp': 76.01,
#   'Percent Humidity': 87,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:25:40'},
#  {'City': 'Taos',
#   'Lat': 36.4072,
#   'Lng': -105.5731,
#   'Max Temp': 61.2,
#   'Percent Humidity': 15,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:25:41'},
#  {'City': 'Kuteynykove',
#   'Lat': 47.8123,
#   'Lng': 38.2882,
#   'Max Temp': 54.05,
#   'Percent Humidity': 62,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 5.66,
#   'Country': 'UA',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:25:41'},
#  {'City': 'Coolum Beach',
#   'Lat': -26.5333,
#   'Lng': 153.1,
#   'Max Temp': 79.11,
#   'Percent Humidity': 78,
#   'Percent Cloudiness': 11,
#   'Wind Speed': 10.31,
#   'Country': 'AU',
#   'Current Description': 'few clouds',
#   'Date': '2022-04-29 02:25:42'},
#  {'City': 'Jales',
#   'Lat': -20.2689,
#   'Lng': -50.5458,
#   'Max Temp': 73.56,
#   'Percent Humidity': 45,
#   'Percent Cloudiness': 39,
#   'Wind Speed': 6.87,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:25:42'},
#  {'City': 'Turtas',
#   'Lat': 58.9417,
#   'Lng': 69.1325,
#   'Max Temp': 44.8,
#   'Percent Humidity': 82,
#   'Percent Cloudiness': 52,
#   'Wind Speed': 12.03,
#   'Country': 'RU',
#   'Current Description': 'broken clouds',
#   'Date': '2022-04-29 02:25:43'},
#  {'City': 'Mizdah',
#   'Lat': 31.4451,
#   'Lng': 12.9801,
#   'Max Temp': 55.49,
#   'Percent Humidity': 55,
#   'Percent Cloudiness': 3,
#   'Wind Speed': 8.75,
#   'Country': 'LY',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:25:43'},
#  {'City': 'Kapoeta',
#   'Lat': 4.7717,
#   'Lng': 33.5903,
#   'Max Temp': 73.27,
#   'Percent Humidity': 72,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 5.32,
#   'Country': 'SS',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:25:44'},
#  {'City': 'Santo Tomas',
#   'Lat': 14.1079,
#   'Lng': 121.1414,
#   'Max Temp': 89.85,
#   'Percent Humidity': 50,
#   'Percent Cloudiness': 96,
#   'Wind Speed': 10.38,
#   'Country': 'PH',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:25:44'},
#  {'City': 'Soma',
#   'Lat': 39.1855,
#   'Lng': 27.6094,
#   'Max Temp': 50.72,
#   'Percent Humidity': 88,
#   'Percent Cloudiness': 63,
#   'Wind Speed': 7.99,
#   'Country': 'TR',
#   'Current Description': 'broken clouds',
#   'Date': '2022-04-29 02:25:45'},
#  {'City': 'Yerbogachen',
#   'Lat': 61.2767,
#   'Lng': 108.0108,
#   'Max Temp': 42.62,
#   'Percent Humidity': 69,
#   'Percent Cloudiness': 62,
#   'Wind Speed': 10.89,
#   'Country': 'RU',
#   'Current Description': 'broken clouds',
#   'Date': '2022-04-29 02:25:46'},
#  {'City': 'Riyadh',
#   'Lat': 24.6877,
#   'Lng': 46.7219,
#   'Max Temp': 69.94,
#   'Percent Humidity': 64,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 7.54,
#   'Country': 'SA',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:25:46'},
#  {'City': 'Kokstad',
#   'Lat': -30.5472,
#   'Lng': 29.4241,
#   'Max Temp': 47.7,
#   'Percent Humidity': 64,
#   'Percent Cloudiness': 1,
#   'Wind Speed': 5.86,
#   'Country': 'ZA',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:25:47'},
#  {'City': 'Shingu',
#   'Lat': 33.7333,
#   'Lng': 135.9833,
#   'Max Temp': 61.5,
#   'Percent Humidity': 97,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 8.7,
#   'Country': 'JP',
#   'Current Description': 'moderate rain',
#   'Date': '2022-04-29 02:25:47'},
#  {'City': 'Huntington',
#   'Lat': 38.4193,
#   'Lng': -82.4452,
#   'Max Temp': 55.33,
#   'Percent Humidity': 63,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 3.96,
#   'Country': 'US',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:25:48'},
#  {'City': 'Liuzhou',
#   'Lat': 24.3126,
#   'Lng': 109.3892,
#   'Max Temp': 75.04,
#   'Percent Humidity': 77,
#   'Percent Cloudiness': 49,
#   'Wind Speed': 10.92,
#   'Country': 'CN',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:25:48'},
#  {'City': 'Ust-Kuyga',
#   'Lat': 70.0167,
#   'Lng': 135.6,
#   'Max Temp': 16.03,
#   'Percent Humidity': 86,
#   'Percent Cloudiness': 48,
#   'Wind Speed': 8.14,
#   'Country': 'RU',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:25:49'},
#  {'City': 'Artyom',
#   'Lat': 40.4723,
#   'Lng': 50.333,
#   'Max Temp': 55.54,
#   'Percent Humidity': 75,
#   'Percent Cloudiness': 1,
#   'Wind Speed': 5.37,
#   'Country': 'AZ',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:25:49'},
#  {'City': 'Katobu',
#   'Lat': -4.9408,
#   'Lng': 122.5276,
#   'Max Temp': 86.23,
#   'Percent Humidity': 63,
#   'Percent Cloudiness': 80,
#   'Wind Speed': 4.7,
#   'Country': 'ID',
#   'Current Description': 'broken clouds',
#   'Date': '2022-04-29 02:25:50'},
#  {'City': 'Lohja',
#   'Lat': 60.2486,
#   'Lng': 24.0653,
#   'Max Temp': 32.45,
#   'Percent Humidity': 100,
#   'Percent Cloudiness': 6,
#   'Wind Speed': 6.15,
#   'Country': 'FI',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:25:50'},
#  {'City': 'Karauli',
#   'Lat': 26.5,
#   'Lng': 77.0167,
#   'Max Temp': 91.89,
#   'Percent Humidity': 13,
#   'Percent Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'IN',
#   'Current Description': 'broken clouds',
#   'Date': '2022-04-29 02:25:51'},
#  {'City': 'Luwuk',
#   'Lat': -0.9516,
#   'Lng': 122.7875,
#   'Max Temp': 85.78,
#   'Percent Humidity': 68,
#   'Percent Cloudiness': 86,
#   'Wind Speed': 2.86,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:25:52'},
#  {'City': 'Asyut',
#   'Lat': 27.181,
#   'Lng': 31.1837,
#   'Max Temp': 77.49,
#   'Percent Humidity': 10,
#   'Percent Cloudiness': 32,
#   'Wind Speed': 6.51,
#   'Country': 'EG',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:25:52'},
#  {'City': 'Narsaq',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 43.02,
#   'Percent Humidity': 83,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 1.16,
#   'Country': 'GL',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:25:53'},
#  {'City': 'Marawi',
#   'Lat': 7.9986,
#   'Lng': 124.2928,
#   'Max Temp': 80.11,
#   'Percent Humidity': 69,
#   'Percent Cloudiness': 84,
#   'Wind Speed': 3.56,
#   'Country': 'PH',
#   'Current Description': 'broken clouds',
#   'Date': '2022-04-29 02:25:53'},
#  {'City': 'Kaduqli',
#   'Lat': 11.0167,
#   'Lng': 29.7167,
#   'Max Temp': 84.11,
#   'Percent Humidity': 49,
#   'Percent Cloudiness': 95,
#   'Wind Speed': 5.14,
#   'Country': 'SD',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:25:54'},
#  {'City': 'Berlevag',
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp': 22.8,
#   'Percent Humidity': 73,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 21.9,
#   'Country': 'NO',
#   'Current Description': 'light snow',
#   'Date': '2022-04-29 02:25:54'},
#  {'City': 'Khasan',
#   'Lat': 42.4308,
#   'Lng': 130.6434,
#   'Max Temp': 48.88,
#   'Percent Humidity': 54,
#   'Percent Cloudiness': 20,
#   'Wind Speed': 9.82,
#   'Country': 'RU',
#   'Current Description': 'few clouds',
#   'Date': '2022-04-29 02:25:55'},
#  {'City': 'Batagay',
#   'Lat': 67.6333,
#   'Lng': 134.6333,
#   'Max Temp': 22.33,
#   'Percent Humidity': 74,
#   'Percent Cloudiness': 97,
#   'Wind Speed': 1.16,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:25:56'},
#  {'City': 'Westport',
#   'Lat': 41.1415,
#   'Lng': -73.3579,
#   'Max Temp': 48.81,
#   'Percent Humidity': 32,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:25:56'},
#  {'City': 'Maumere',
#   'Lat': -8.6199,
#   'Lng': 122.2111,
#   'Max Temp': 84.13,
#   'Percent Humidity': 69,
#   'Percent Cloudiness': 75,
#   'Wind Speed': 2.73,
#   'Country': 'ID',
#   'Current Description': 'broken clouds',
#   'Date': '2022-04-29 02:25:57'},
#  {'City': 'Ormara',
#   'Lat': 25.2088,
#   'Lng': 64.6357,
#   'Max Temp': 83.3,
#   'Percent Humidity': 79,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 14.43,
#   'Country': 'PK',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:25:57'},
#  {'City': 'Leh',
#   'Lat': 34.1667,
#   'Lng': 77.5833,
#   'Max Temp': 40.5,
#   'Percent Humidity': 76,
#   'Percent Cloudiness': 99,
#   'Wind Speed': 3.51,
#   'Country': 'IN',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:26:58'},
#  {'City': 'Pindiga',
#   'Lat': 9.9833,
#   'Lng': 10.9333,
#   'Max Temp': 79.59,
#   'Percent Humidity': 57,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 10.42,
#   'Country': 'NG',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:26:58'},
#  {'City': 'Buala',
#   'Lat': -8.145,
#   'Lng': 159.5921,
#   'Max Temp': 85.69,
#   'Percent Humidity': 69,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 4.09,
#   'Country': 'SB',
#   'Current Description': 'light rain',
#   'Date': '2022-04-29 02:26:59'},
#  {'City': 'Bereda',
#   'Lat': 43.2686,
#   'Lng': -7.5406,
#   'Max Temp': 46.58,
#   'Percent Humidity': 100,
#   'Percent Cloudiness': 39,
#   'Wind Speed': 1.79,
#   'Country': 'ES',
#   'Current Description': 'scattered clouds',
#   'Date': '2022-04-29 02:26:59'},
#  {'City': 'Sur',
#   'Lat': 22.5667,
#   'Lng': 59.5289,
#   'Max Temp': 87.94,
#   'Percent Humidity': 39,
#   'Percent Cloudiness': 60,
#   'Wind Speed': 9.42,
#   'Country': 'OM',
#   'Current Description': 'broken clouds',
#   'Date': '2022-04-29 02:27:00'},
#  {'City': 'Zeerust',
#   'Lat': -25.5369,
#   'Lng': 26.0751,
#   'Max Temp': 53.19,
#   'Percent Humidity': 73,
#   'Percent Cloudiness': 2,
#   'Wind Speed': 2.15,
#   'Country': 'ZA',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:27:00'},
#  {'City': 'Liverpool',
#   'Lat': 53.4106,
#   'Lng': -2.9779,
#   'Max Temp': 47.61,
#   'Percent Humidity': 76,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 5.75,
#   'Country': 'GB',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:27:01'},
#  {'City': 'Espinosa',
#   'Lat': -14.9261,
#   'Lng': -42.8192,
#   'Max Temp': 67.57,
#   'Percent Humidity': 70,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 4.92,
#   'Country': 'BR',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:27:02'},
#  {'City': 'Pitimbu',
#   'Lat': -7.4706,
#   'Lng': -34.8086,
#   'Max Temp': 75.79,
#   'Percent Humidity': 79,
#   'Percent Cloudiness': 76,
#   'Wind Speed': 10.8,
#   'Country': 'BR',
#   'Current Description': 'broken clouds',
#   'Date': '2022-04-29 02:27:02'},
#  {'City': 'Taman',
#   'Lat': 45.2117,
#   'Lng': 36.7161,
#   'Max Temp': 56.71,
#   'Percent Humidity': 75,
#   'Percent Cloudiness': 99,
#   'Wind Speed': 12.55,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:27:03'},
#  {'City': 'Abu Dhabi',
#   'Lat': 24.4667,
#   'Lng': 54.3667,
#   'Max Temp': 84.22,
#   'Percent Humidity': 49,
#   'Percent Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'AE',
#   'Current Description': 'clear sky',
#   'Date': '2022-04-29 02:27:03'},
#  {'City': 'Shimoni',
#   'Lat': -4.6476,
#   'Lng': 39.3817,
#   'Max Temp': 77.52,
#   'Percent Humidity': 82,
#   'Percent Cloudiness': 86,
#   'Wind Speed': 14.05,
#   'Country': 'KE',
#   'Current Description': 'light rain',
#   'Date': '2022-04-29 02:27:04'},
#  {'City': 'Amapa',
#   'Lat': 1,
#   'Lng': -52,
#   'Max Temp': 72.45,
#   'Percent Humidity': 99,
#   'Percent Cloudiness': 100,
#   'Wind Speed': 2.19,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds',
#   'Date': '2022-04-29 02:27:04'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Percent Humidity  \
# 0         Tottori  35.5000  134.2333     55.47                94
# 1         Kushiro  42.9750  144.3747     47.73                48
# 2       Bathsheba  13.2167  -59.5167     79.41                89
# 3           Ipora -16.4419  -51.1178     68.36                59
# 4      Ust-Tsilma  65.4410   52.1498     25.27                82
# 5         Rikitea -23.1203 -134.9692     77.05                69
# 6          Faanui -16.4833 -151.7500     81.46                72
# 7         Ushuaia -54.8000  -68.3000     40.66                87
# 8            Brae  60.3964   -1.3530     44.80                81
# 9  Ribeira Grande  38.5167  -28.7000     63.59                84
#
#    Percent Cloudiness  Wind Speed Country Current Description  \
# 0                  75        2.30      JP         shower rain
# 1                  98       15.41      JP     overcast clouds
# 2                  40       12.66      BB    scattered clouds
# 3                   4        3.11      BR           clear sky
# 4                  25        8.41      RU    scattered clouds
# 5                   0       18.34      PF           clear sky
# 6                   0       21.54      PF          light rain
# 7                  40       27.63      AR    scattered clouds
# 8                  94        5.68      GB     overcast clouds
# 9                 100       20.71      PT          light rain
#
#                   Date
# 0  2022-04-29 02:04:59
# 1  2022-04-29 02:06:06
# 2  2022-04-29 02:06:06
# 3  2022-04-29 02:02:34
# 4  2022-04-29 02:06:08
# 5  2022-04-29 02:00:40
# 6  2022-04-29 02:06:08
# 7  2022-04-29 02:06:09
# 8  2022-04-29 02:06:09
# 9  2022-04-29 02:06:10

# %%
#  reorder the DataFrame
new_column_order = ['City', 'Country', 'Date', 'Current Description', 'Lat', 'Lng', 'Max Temp', 'Percent Humidity', 'Percent Cloudiness', 'Wind Speed']
city_data_df = city_data_df[new_column_order]

# view city_data_df
city_data_df
# Out:
#            City Country                 Date Current Description      Lat  \
# 0       Tottori      JP  2022-04-29 02:04:59         shower rain  35.5000
# 1       Kushiro      JP  2022-04-29 02:06:06     overcast clouds  42.9750
# 2     Bathsheba      BB  2022-04-29 02:06:06    scattered clouds  13.2167
# 3         Ipora      BR  2022-04-29 02:02:34           clear sky -16.4419
# 4    Ust-Tsilma      RU  2022-04-29 02:06:08    scattered clouds  65.4410
# ..          ...     ...                  ...                 ...      ...
# 696     Pitimbu      BR  2022-04-29 02:27:02       broken clouds  -7.4706
# 697       Taman      RU  2022-04-29 02:27:03     overcast clouds  45.2117
# 698   Abu Dhabi      AE  2022-04-29 02:27:03           clear sky  24.4667
# 699     Shimoni      KE  2022-04-29 02:27:04          light rain  -4.6476
# 700       Amapa      BR  2022-04-29 02:27:04     overcast clouds   1.0000
#
#           Lng  Max Temp  Percent Humidity  Percent Cloudiness  Wind Speed
# 0    134.2333     55.47                94                  75        2.30
# 1    144.3747     47.73                48                  98       15.41
# 2    -59.5167     79.41                89                  40       12.66
# 3    -51.1178     68.36                59                   4        3.11
# 4     52.1498     25.27                82                  25        8.41
# ..        ...       ...               ...                 ...         ...
# 696  -34.8086     75.79                79                  76       10.80
# 697   36.7161     56.71                75                  99       12.55
# 698   54.3667     84.22                49                   0        8.05
# 699   39.3817     77.52                82                  86       14.05
# 700  -52.0000     72.45                99                 100        2.19
#
# [701 rows x 10 columns]

# %%
# Create the output file (CSV).
output_data_file = "./Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
